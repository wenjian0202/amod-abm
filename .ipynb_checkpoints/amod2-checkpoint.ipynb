# %%
import time
import csv
import copy
import pandas as pd
import argparse
import numpy as np
import random
from multiprocessing import *
import mplleaflet
import matplotlib.pyplot as plt
from collections import deque

from lib.OsrmEngine import *
from lib.Agents import *
from lib.Demand import *

# %%
exe_loc = './osrm-backend-5.6.0/build/osrm-routed'
map_loc = './osrm-backend-5.6.0/greater-london-latest.osrm'

osrm = OsrmEngine(exe_loc, map_loc)
osrm.start_server()
osrm = OsrmEngine(exe_loc, map_loc)
osrm.start_server()
# Out:
# The routing server "http://0.0.0.0:5000" is killed
# The routing server "http://0.0.0.0:5000" starts running
# The routing server "http://0.0.0.0:5000" is killed
# The routing server "http://0.0.0.0:5000" starts running

# %%
model = Model(10, demand, V=20, K=2)
T = 0

B_W = 1.5
B_V = 1.0

# %%
stime = time.time()
for T in range(0,300,30):
    model.dispatch_at_time(osrm, T)
etime = time.time()
runtime = etime - stime
# Out:
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 0.000, 0 requests, in which 0 in queue
# veh 0 at (0.0635797, 51.3697727) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 1 at (0.0608173, 51.3766992) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0646510, 51.3930789) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0791536, 51.3847255) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0903638, 51.3843779) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0863293, 51.3438825) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0487849, 51.3685010) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0552989, 51.3626464) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 11 at (0.0661365, 51.3780783) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0823688, 51.3601608) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0829193, 51.3785440) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0600655, 51.3685206) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 15 at (0.0536231, 51.4048691) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0674082, 51.3776694) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 17 at (0.1227267, 51.3861819) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 18 at (0.1032335, 51.3778438) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 19 at (0.0578694, 51.3930047) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 30.000, 2 requests, in which 2 in queue
# req 0 from (0.0628968, 51.3712046) to (0.0739150, 51.3585900) at t = 8.367
#   latest pickup at t = 488.367, latest dropoff at t = 984.367
#   pickup at t = -1.000, dropoff at t = -1.000
# req 1 from (0.0558905, 51.3687900) to (0.0642029, 51.3652591) at t = 18.879
#   latest pickup at t = 498.879, latest dropoff at t = 828.279
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0635797, 51.3697727) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2378.6, duration = 275.7，cost = 289.6
#     pickup: req 0 at (0.0628968, 51.3712046), distance = 185.7, duration = 27.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 2192.9, duration = 248.0
# veh 1 at (0.0608173, 51.3766992) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0646510, 51.3930789) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0791536, 51.3847255) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0903638, 51.3843779) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0863293, 51.3438825) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0487849, 51.3685010) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0552989, 51.3626464) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 11 at (0.0661365, 51.3780783) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0823688, 51.3601608) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0829193, 51.3785440) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0600655, 51.3685206) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 1469.0, duration = 241.6，cost = 280.1
#     pickup: req 1 at (0.0558905, 51.3687900), distance = 439.2, duration = 76.9
#     dropoff: req 1 at (0.0642029, 51.3652591), distance = 1029.8, duration = 164.7
# veh 15 at (0.0536231, 51.4048691) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0674082, 51.3776694) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 17 at (0.1227267, 51.3861819) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 18 at (0.1032335, 51.3778438) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 19 at (0.0578694, 51.3930047) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 60.000, 5 requests, in which 3 in queue
# req 2 from (0.0907837, 51.3795975) to (0.0746622, 51.3897401) at t = 36.502
#   latest pickup at t = 516.502, latest dropoff at t = 1046.102
#   pickup at t = -1.000, dropoff at t = -1.000
# req 3 from (0.0525978, 51.3391907) to (0.1005414, 51.3756921) at t = 40.897
#   latest pickup at t = 520.897, latest dropoff at t = 1732.097
#   pickup at t = -1.000, dropoff at t = -1.000
# req 4 from (0.0413928, 51.3718735) to (0.0980168, 51.3526494) at t = 49.043
#   latest pickup at t = 529.043, latest dropoff at t = 1540.243
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0627826, 51.3710351) when t = 60.000; occupancy = 1/2;
#   service distance/time travelled: 197.3, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 2181.3, duration = 245.7，cost = 245.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 2181.3, duration = 245.7
# veh 1 at (0.0608173, 51.3766992) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0646510, 51.3930789) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0791536, 51.3847255) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0903638, 51.3843779) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2803.1, duration = 340.9，cost = 378.9
#     pickup: req 2 at (0.0907837, 51.3795975), distance = 697.2, duration = 76.1
#     dropoff: req 2 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 7 at (0.0863293, 51.3438825) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0487849, 51.3685010) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 11901.0, duration = 1005.2，cost = 1205.0
#     pickup: req 3 at (0.0525978, 51.3391907), distance = 5129.6, duration = 399.6
#     dropoff: req 3 at (0.1005414, 51.3756921), distance = 6771.4, duration = 605.6
# veh 10 at (0.0552989, 51.3626464) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6821.4, duration = 697.4，cost = 793.3
#     pickup: req 4 at (0.0413928, 51.3718735), distance = 1732.4, duration = 191.8
#     dropoff: req 4 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 11 at (0.0661365, 51.3780783) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0823688, 51.3601608) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0829193, 51.3785440) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0583682, 51.3691630) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 149.6, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 1319.4, duration = 211.6，cost = 235.1
#     pickup: req 1 at (0.0558905, 51.3687900), distance = 289.6, duration = 46.9
#     dropoff: req 1 at (0.0642029, 51.3652591), distance = 1029.8, duration = 164.7
# veh 15 at (0.0536231, 51.4048691) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0674082, 51.3776694) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 17 at (0.1227267, 51.3861819) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 18 at (0.1032335, 51.3778438) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 19 at (0.0578694, 51.3930047) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 90.000, 7 requests, in which 2 in queue
# req 5 from (0.1176802, 51.3898180) to (0.1004065, 51.3757290) at t = 78.186
#   latest pickup at t = 558.186, latest dropoff at t = 1188.186
#   pickup at t = -1.000, dropoff at t = -1.000
# req 6 from (0.0687732, 51.3715380) to (0.0603542, 51.4061583) at t = 80.026
#   latest pickup at t = 560.026, latest dropoff at t = 1791.226
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0643370, 51.3698661) when t = 90.000; occupancy = 1/2;
#   service distance/time travelled: 413.5, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 1965.1, duration = 215.7，cost = 215.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 1965.1, duration = 215.7
# veh 1 at (0.0608173, 51.3766992) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0646510, 51.3930789) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0791536, 51.3847255) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0917395, 51.3832852) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 234.6, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2568.5, duration = 310.9，cost = 333.9
#     pickup: req 2 at (0.0907837, 51.3795975), distance = 462.6, duration = 46.1
#     dropoff: req 2 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 7 at (0.0863293, 51.3438825) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0475142, 51.3669729) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 290.2, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 11610.8, duration = 975.2，cost = 1160.0
#     pickup: req 3 at (0.0525978, 51.3391907), distance = 4839.4, duration = 369.6
#     dropoff: req 3 at (0.1005414, 51.3756921), distance = 6771.4, duration = 605.6
# veh 10 at (0.0571972, 51.3635386) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 178.3, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6643.1, duration = 667.4，cost = 748.3
#     pickup: req 4 at (0.0413928, 51.3718735), distance = 1554.1, duration = 161.8
#     dropoff: req 4 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 11 at (0.0661365, 51.3780783) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0823688, 51.3601608) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0829193, 51.3785440) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0569526, 51.3696370) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 321.5, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 1147.5, duration = 181.6，cost = 190.1
#     pickup: req 1 at (0.0558905, 51.3687900), distance = 117.7, duration = 16.9
#     dropoff: req 1 at (0.0642029, 51.3652591), distance = 1029.8, duration = 164.7
# veh 15 at (0.0536231, 51.4048691) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0674082, 51.3776694) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7683.7, duration = 793.9，cost = 883.1
#     pickup: req 6 at (0.0687732, 51.3715380), distance = 1429.8, duration = 178.3
#     dropoff: req 6 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 17 at (0.1227267, 51.3861819) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3123.9, duration = 413.1，cost = 462.1
#     pickup: req 5 at (0.1176802, 51.3898180), distance = 661.8, duration = 98.1
#     dropoff: req 5 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 18 at (0.1032335, 51.3778438) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 19 at (0.0578694, 51.3930047) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 120.000, 10 requests, in which 3 in queue
# req 7 from (0.1252152, 51.3955701) to (0.1140902, 51.3871844) at t = 95.218
#   latest pickup at t = 575.218, latest dropoff at t = 1106.418
#   pickup at t = -1.000, dropoff at t = -1.000
# req 8 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 96.545
#   latest pickup at t = 576.545, latest dropoff at t = 2045.345
#   pickup at t = -1.000, dropoff at t = -1.000
# req 9 from (0.0907837, 51.3795975) to (0.0746622, 51.3897401) at t = 108.387
#   latest pickup at t = 588.387, latest dropoff at t = 1117.987
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0655384, 51.3682715) when t = 120.000; occupancy = 1/2;
#   service distance/time travelled: 713.3, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 1665.3, duration = 185.7，cost = 185.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 1665.3, duration = 185.7
# veh 1 at (0.0608173, 51.3766992) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0646510, 51.3930789) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0791536, 51.3847255) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3862.7, duration = 462.2，cost = 560.9
#     pickup: req 9 at (0.0907837, 51.3795975), distance = 1756.8, duration = 197.4
#     dropoff: req 9 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 6 at (0.0916899, 51.3806978) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 540.1, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2263.0, duration = 280.9，cost = 288.9
#     pickup: req 2 at (0.0907837, 51.3795975), distance = 157.1, duration = 16.1
#     dropoff: req 2 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 7 at (0.0863293, 51.3438825) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0425391, 51.3672810) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 643.0, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 11258.0, duration = 945.2，cost = 1115.0
#     pickup: req 3 at (0.0525978, 51.3391907), distance = 4486.6, duration = 339.6
#     dropoff: req 3 at (0.1005414, 51.3756921), distance = 6771.4, duration = 605.6
# veh 10 at (0.0539908, 51.3656618) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 499.9, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6321.5, duration = 637.4，cost = 703.3
#     pickup: req 4 at (0.0413928, 51.3718735), distance = 1232.5, duration = 131.8
#     dropoff: req 4 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 11 at (0.0661365, 51.3780783) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0823688, 51.3601608) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0829193, 51.3785440) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0565466, 51.3694109) when t = 120.000; occupancy = 1/2;
#   service distance/time travelled: 519.2, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 949.8, duration = 151.6，cost = 151.6
#     dropoff: req 1 at (0.0642029, 51.3652591), distance = 949.8, duration = 151.6
# veh 15 at (0.0536231, 51.4048691) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0655695, 51.3754319) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 199.6, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7484.1, duration = 763.9，cost = 838.1
#     pickup: req 6 at (0.0687732, 51.3715380), distance = 1230.2, duration = 148.3
#     dropoff: req 6 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 17 at (0.1220486, 51.3894332) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 268.3, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2855.6, duration = 383.1，cost = 417.1
#     pickup: req 5 at (0.1176802, 51.3898180), distance = 393.5, duration = 68.1
#     dropoff: req 5 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 18 at (0.1032335, 51.3778438) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5731.7, duration = 671.6，cost = 874.6
#     pickup: req 7 at (0.1252152, 51.3955701), distance = 3775.3, duration = 406.0
#     dropoff: req 7 at (0.1140902, 51.3871844), distance = 1956.4, duration = 265.6
# veh 19 at (0.0578694, 51.3930047) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 150.000, 13 requests, in which 4 in queue
# req 8 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 96.545
#   latest pickup at t = 576.545, latest dropoff at t = 2045.345
#   pickup at t = -1.000, dropoff at t = -1.000
# req 10 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 132.977
#   latest pickup at t = 612.977, latest dropoff at t = 2081.777
#   pickup at t = -1.000, dropoff at t = -1.000
# req 11 from (0.0714008, 51.3934361) to (0.0918767, 51.4176560) at t = 134.321
#   latest pickup at t = 614.321, latest dropoff at t = 1611.721
#   pickup at t = -1.000, dropoff at t = -1.000
# req 12 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 137.176
#   latest pickup at t = 617.176, latest dropoff at t = 2085.976
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0636883, 51.3657200) when t = 150.000; occupancy = 1/2;
#   service distance/time travelled: 1007.6, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 1371.0, duration = 155.7，cost = 155.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 1371.0, duration = 155.7
# veh 1 at (0.0608173, 51.3766992) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0646510, 51.3930789) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0806222, 51.3832706) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 194.1, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3668.6, duration = 432.2，cost = 515.9
#     pickup: req 9 at (0.0907837, 51.3795975), distance = 1562.7, duration = 167.4
#     dropoff: req 9 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 6 at (0.0913074, 51.3800754) when t = 150.000; occupancy = 1/2;
#   service distance/time travelled: 776.8, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 2026.3, duration = 250.9，cost = 250.9
#     dropoff: req 2 at (0.0746622, 51.3897401), distance = 2026.3, duration = 250.9
# veh 7 at (0.0863293, 51.3438825) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0389683, 51.3660742) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 1010.5, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 10890.5, duration = 915.2，cost = 1070.0
#     pickup: req 3 at (0.0525978, 51.3391907), distance = 4119.1, duration = 309.6
#     dropoff: req 3 at (0.1005414, 51.3756921), distance = 6771.4, duration = 605.6
# veh 10 at (0.0504242, 51.3674690) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 849.5, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5971.9, duration = 607.4，cost = 658.3
#     pickup: req 4 at (0.0413928, 51.3718735), distance = 882.9, duration = 101.8
#     dropoff: req 4 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 11 at (0.0661365, 51.3780783) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0823688, 51.3601608) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0829193, 51.3785440) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7956.5, duration = 734.5，cost = 852.4
#     pickup: req 11 at (0.0714008, 51.3934361), distance = 2245.6, duration = 235.8
#     dropoff: req 11 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 14 at (0.0581058, 51.3694774) when t = 150.000; occupancy = 1/2;
#   service distance/time travelled: 689.8, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 779.2, duration = 121.6，cost = 121.6
#     dropoff: req 1 at (0.0642029, 51.3652591), distance = 779.2, duration = 121.6
# veh 15 at (0.0536231, 51.4048691) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0677361, 51.3744254) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 404.3, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7279.4, duration = 733.9，cost = 793.1
#     pickup: req 6 at (0.0687732, 51.3715380), distance = 1025.5, duration = 118.3
#     dropoff: req 6 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 17 at (0.1205196, 51.3896359) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 430.0, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2693.9, duration = 353.1，cost = 372.1
#     pickup: req 5 at (0.1176802, 51.3898180), distance = 231.8, duration = 38.1
#     dropoff: req 5 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 18 at (0.1036245, 51.3787573) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 182.2, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5549.5, duration = 641.6，cost = 829.6
#     pickup: req 7 at (0.1252152, 51.3955701), distance = 3593.1, duration = 376.0
#     dropoff: req 7 at (0.1140902, 51.3871844), distance = 1956.4, duration = 265.6
# veh 19 at (0.0578694, 51.3930047) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 180.000, 17 requests, in which 7 in queue
# req 8 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 96.545
#   latest pickup at t = 576.545, latest dropoff at t = 2045.345
#   pickup at t = -1.000, dropoff at t = -1.000
# req 10 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 132.977
#   latest pickup at t = 612.977, latest dropoff at t = 2081.777
#   pickup at t = -1.000, dropoff at t = -1.000
# req 12 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 137.176
#   latest pickup at t = 617.176, latest dropoff at t = 2085.976
#   pickup at t = -1.000, dropoff at t = -1.000
# req 13 from (0.0413928, 51.3718735) to (0.0980168, 51.3526494) at t = 164.794
#   latest pickup at t = 644.794, latest dropoff at t = 1655.994
#   pickup at t = -1.000, dropoff at t = -1.000
# req 14 from (0.0687732, 51.3715380) to (0.0603542, 51.4061583) at t = 167.784
#   latest pickup at t = 647.784, latest dropoff at t = 1878.984
#   pickup at t = -1.000, dropoff at t = -1.000
# req 15 from (0.1229523, 51.3968114) to (0.1015619, 51.3777827) at t = 173.626
#   latest pickup at t = 653.626, latest dropoff at t = 1764.226
#   pickup at t = -1.000, dropoff at t = -1.000
# req 16 from (0.0907837, 51.3795975) to (0.0746622, 51.3897401) at t = 177.797
#   latest pickup at t = 657.797, latest dropoff at t = 1187.397
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0635916, 51.3639303) when t = 180.000; occupancy = 1/2;
#   service distance/time travelled: 1241.1, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 1137.5, duration = 125.7，cost = 125.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 1137.5, duration = 125.7
# veh 1 at (0.0608173, 51.3766992) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7142.0, duration = 787.5，cost = 928.5
#     pickup: req 13 at (0.0413928, 51.3718735), distance = 2053.0, duration = 281.9
#     dropoff: req 13 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 2 at (0.0646510, 51.3930789) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0821116, 51.3818101) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 388.3, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3474.4, duration = 402.2，cost = 470.9
#     pickup: req 9 at (0.0907837, 51.3795975), distance = 1368.5, duration = 137.4
#     dropoff: req 9 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 6 at (0.0920992, 51.3827153) when t = 180.000; occupancy = 1/2;
#   service distance/time travelled: 1080.0, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 2486.1, duration = 303.2，cost = 625.6
#     pickup: req 16 at (0.0907837, 51.3795975), distance = 380.2, duration = 38.4
#     dropoff: req 2 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
#     dropoff: req 16 at (0.0746622, 51.3897401), distance = 0.0, duration = 0.0
# veh 7 at (0.0863293, 51.3438825) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0391451, 51.3618982) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 1415.4, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 10485.6, duration = 885.2，cost = 1025.0
#     pickup: req 3 at (0.0525978, 51.3391907), distance = 3714.2, duration = 279.6
#     dropoff: req 3 at (0.1005414, 51.3756921), distance = 6771.4, duration = 605.6
# veh 10 at (0.0479872, 51.3703054) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 1180.8, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5640.6, duration = 577.4，cost = 613.3
#     pickup: req 4 at (0.0413928, 51.3718735), distance = 551.6, duration = 71.8
#     dropoff: req 4 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 11 at (0.0661365, 51.3780783) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7683.7, duration = 793.9，cost = 883.1
#     pickup: req 14 at (0.0687732, 51.3715380), distance = 1429.8, duration = 178.3
#     dropoff: req 14 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 12 at (0.0823688, 51.3601608) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0796761, 51.3790420) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 293.8, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7662.7, duration = 704.5，cost = 807.4
#     pickup: req 11 at (0.0714008, 51.3934361), distance = 1951.8, duration = 205.8
#     dropoff: req 11 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 14 at (0.0595210, 51.3685093) when t = 180.000; occupancy = 1/2;
#   service distance/time travelled: 868.1, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 600.9, duration = 91.6，cost = 91.6
#     dropoff: req 1 at (0.0642029, 51.3652591), distance = 600.9, duration = 91.6
# veh 15 at (0.0536231, 51.4048691) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0694946, 51.3733662) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 619.6, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7064.1, duration = 703.9，cost = 748.1
#     pickup: req 6 at (0.0687732, 51.3715380), distance = 810.2, duration = 88.3
#     dropoff: req 6 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 17 at (0.1184322, 51.3897562) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 605.3, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2518.6, duration = 323.1，cost = 327.1
#     pickup: req 5 at (0.1176802, 51.3898180), distance = 56.5, duration = 8.1
#     dropoff: req 5 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 18 at (0.1065871, 51.3786695) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 422.6, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5309.1, duration = 611.6，cost = 784.6
#     pickup: req 7 at (0.1252152, 51.3955701), distance = 3352.7, duration = 346.0
#     dropoff: req 7 at (0.1140902, 51.3871844), distance = 1956.4, duration = 265.6
# veh 19 at (0.0578694, 51.3930047) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 210.000, 20 requests, in which 7 in queue
# req 8 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 96.545
#   latest pickup at t = 576.545, latest dropoff at t = 2045.345
#   pickup at t = -1.000, dropoff at t = -1.000
# req 10 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 132.977
#   latest pickup at t = 612.977, latest dropoff at t = 2081.777
#   pickup at t = -1.000, dropoff at t = -1.000
# req 12 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 137.176
#   latest pickup at t = 617.176, latest dropoff at t = 2085.976
#   pickup at t = -1.000, dropoff at t = -1.000
# req 15 from (0.1229523, 51.3968114) to (0.1015619, 51.3777827) at t = 173.626
#   latest pickup at t = 653.626, latest dropoff at t = 1764.226
#   pickup at t = -1.000, dropoff at t = -1.000
# req 17 from (0.0687732, 51.3715380) to (0.0603542, 51.4061583) at t = 199.266
#   latest pickup at t = 679.266, latest dropoff at t = 1910.466
#   pickup at t = -1.000, dropoff at t = -1.000
# req 18 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 203.359
#   latest pickup at t = 683.359, latest dropoff at t = 2152.159
#   pickup at t = -1.000, dropoff at t = -1.000
# req 19 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 207.339
#   latest pickup at t = 687.339, latest dropoff at t = 2156.139
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0640974, 51.3620588) when t = 210.000; occupancy = 1/2;
#   service distance/time travelled: 1449.7, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 928.9, duration = 95.7，cost = 95.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 928.9, duration = 95.7
# veh 1 at (0.0602515, 51.3734525) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 201.9, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6940.1, duration = 757.5，cost = 883.5
#     pickup: req 13 at (0.0413928, 51.3718735), distance = 1851.1, duration = 251.9
#     dropoff: req 13 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 2 at (0.0646510, 51.3930789) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0850189, 51.3810694) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 658.9, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3203.8, duration = 372.2，cost = 425.9
#     pickup: req 9 at (0.0907837, 51.3795975), distance = 1097.9, duration = 107.4
#     dropoff: req 9 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 6 at (0.0913032, 51.3800687) when t = 210.000; occupancy = 1/2;
#   service distance/time travelled: 1381.9, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 2184.1, duration = 273.2，cost = 550.6
#     pickup: req 16 at (0.0907837, 51.3795975), distance = 78.2, duration = 8.4
#     dropoff: req 2 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
#     dropoff: req 16 at (0.0746622, 51.3897401), distance = 0.0, duration = 0.0
# veh 7 at (0.0863293, 51.3438825) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0376163, 51.3581833) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 1820.3, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 10080.7, duration = 855.2，cost = 980.0
#     pickup: req 3 at (0.0525978, 51.3391907), distance = 3309.3, duration = 249.6
#     dropoff: req 3 at (0.1005414, 51.3756921), distance = 6771.4, duration = 605.6
# veh 10 at (0.0454145, 51.3715866) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 1442.4, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5379.0, duration = 547.4，cost = 568.3
#     pickup: req 4 at (0.0413928, 51.3718735), distance = 290.0, duration = 41.8
#     dropoff: req 4 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 11 at (0.0655695, 51.3754319) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 199.6, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7484.1, duration = 763.9，cost = 838.1
#     pickup: req 14 at (0.0687732, 51.3715380), distance = 1230.2, duration = 148.3
#     dropoff: req 14 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 12 at (0.0823688, 51.3601608) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0803546, 51.3812212) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 604.6, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7351.9, duration = 674.5，cost = 762.4
#     pickup: req 11 at (0.0714008, 51.3934361), distance = 1641.0, duration = 175.8
# ...
#   pickup at t = -1.000, dropoff at t = -1.000
# req 20 from (0.0687732, 51.3715380) to (0.0603542, 51.4061583) at t = 218.251
#   latest pickup at t = 698.251, latest dropoff at t = 1929.451
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0651051, 51.3599745) when t = 240.000; occupancy = 1/2;
#   service distance/time travelled: 1679.4, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 699.2, duration = 65.7，cost = 65.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 699.2, duration = 65.7
# veh 1 at (0.0588874, 51.3722356) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 404.9, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6737.1, duration = 727.5，cost = 838.5
#     pickup: req 13 at (0.0413928, 51.3718735), distance = 1648.1, duration = 221.9
#     dropoff: req 13 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 2 at (0.0646510, 51.3930789) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0664115, 51.3875321) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0774516, 51.3649371) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8855.7, duration = 907.1，cost = 1052.8
#     pickup: req 20 at (0.0687732, 51.3715380), distance = 2601.8, duration = 291.5
#     dropoff: req 20 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 5 at (0.0884672, 51.3826522) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 969.7, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2893.0, duration = 342.2，cost = 380.9
#     pickup: req 9 at (0.0907837, 51.3795975), distance = 787.1, duration = 77.4
#     dropoff: req 9 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 6 at (0.0916915, 51.3807004) when t = 240.000; occupancy = 2/2;
#   service distance/time travelled: 1617.6, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 1948.5, duration = 243.2，cost = 486.4
#     dropoff: req 2 at (0.0746622, 51.3897401), distance = 1948.5, duration = 243.2
#     dropoff: req 16 at (0.0746622, 51.3897401), distance = 0.0, duration = 0.0
# veh 7 at (0.0863293, 51.3438825) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.0348123, 51.3553380) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 2225.2, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 9675.8, duration = 825.2，cost = 935.0
#     pickup: req 3 at (0.0525978, 51.3391907), distance = 2904.4, duration = 219.6
#     dropoff: req 3 at (0.1005414, 51.3756921), distance = 6771.4, duration = 605.6
# veh 10 at (0.0425479, 51.3716676) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 1650.6, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5170.8, duration = 517.4，cost = 523.3
#     pickup: req 4 at (0.0413928, 51.3718735), distance = 81.8, duration = 11.8
#     dropoff: req 4 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 11 at (0.0677361, 51.3744254) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 404.3, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7279.4, duration = 733.9，cost = 793.1
#     pickup: req 14 at (0.0687732, 51.3715380), distance = 1025.5, duration = 118.3
#     dropoff: req 14 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 12 at (0.0823688, 51.3601608) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0779201, 51.3829247) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 924.6, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7031.9, duration = 644.5，cost = 717.4
#     pickup: req 11 at (0.0714008, 51.3934361), distance = 1321.0, duration = 145.8
#     dropoff: req 11 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 14 at (0.0623466, 51.3655160) when t = 240.000; occupancy = 1/2;
#   service distance/time travelled: 1242.6, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 7408.4, duration = 753.9，cost = 854.7
#     dropoff: req 1 at (0.0642029, 51.3652591), distance = 206.9, duration = 31.6
#     pickup: req 17 at (0.0687732, 51.3715380), distance = 947.6, duration = 106.7
#     dropoff: req 17 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 15 at (0.0536231, 51.4048691) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0706511, 51.3702884) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 1178.2, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6505.5, duration = 643.9，cost = 658.1
#     pickup: req 6 at (0.0687732, 51.3715380), distance = 251.6, duration = 28.3
#     dropoff: req 6 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 17 at (0.1147410, 51.3919354) when t = 240.000; occupancy = 1/2;
#   service distance/time travelled: 1031.6, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 6318.4, duration = 816.9，cost = 1653.0
#     pickup: req 15 at (0.1229523, 51.3968114), distance = 1650.1, duration = 240.1
#     dropoff: req 5 at (0.1004065, 51.3757290), distance = 4069.4, duration = 476.0
#     dropoff: req 15 at (0.1015619, 51.3777827), distance = 598.9, duration = 100.8
# veh 18 at (0.1076093, 51.3829181) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 1121.9, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4609.8, duration = 551.6，cost = 694.6
#     pickup: req 7 at (0.1252152, 51.3955701), distance = 2653.4, duration = 286.0
#     dropoff: req 7 at (0.1140902, 51.3871844), distance = 1956.4, duration = 265.6
# veh 19 at (0.0578694, 51.3930047) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 270.000, 25 requests, in which 9 in queue
# req 8 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 96.545
#   latest pickup at t = 576.545, latest dropoff at t = 2045.345
#   pickup at t = -1.000, dropoff at t = -1.000
# req 10 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 132.977
#   latest pickup at t = 612.977, latest dropoff at t = 2081.777
#   pickup at t = -1.000, dropoff at t = -1.000
# req 12 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 137.176
#   latest pickup at t = 617.176, latest dropoff at t = 2085.976
#   pickup at t = -1.000, dropoff at t = -1.000
# req 18 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 203.359
#   latest pickup at t = 683.359, latest dropoff at t = 2152.159
#   pickup at t = -1.000, dropoff at t = -1.000
# req 19 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 207.339
#   latest pickup at t = 687.339, latest dropoff at t = 2156.139
#   pickup at t = -1.000, dropoff at t = -1.000
# req 21 from (0.0651036, 51.4226657) to (0.1101851, 51.4118164) at t = 244.722
#   latest pickup at t = 724.722, latest dropoff at t = 1699.922
#   pickup at t = -1.000, dropoff at t = -1.000
# req 22 from (0.0919035, 51.4175855) to (0.0712996, 51.3933688) at t = 251.977
#   latest pickup at t = 731.977, latest dropoff at t = 1721.377
#   pickup at t = -1.000, dropoff at t = -1.000
# req 23 from (0.0713160, 51.3724747) to (0.0843372, 51.3798996) at t = 257.500
#   latest pickup at t = 737.500, latest dropoff at t = 1175.700
#   pickup at t = -1.000, dropoff at t = -1.000
# req 24 from (0.0713160, 51.3724747) to (0.0843372, 51.3798996) at t = 269.472
#   latest pickup at t = 749.472, latest dropoff at t = 1187.672
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0690161, 51.3594887) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 1999.3, 240.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 379.3, duration = 35.7，cost = 35.7
#     dropoff: req 0 at (0.0739150, 51.3585900), distance = 379.3, duration = 35.7
# veh 1 at (0.0564387, 51.3713389) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 608.2, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6533.8, duration = 697.5，cost = 793.5
#     pickup: req 13 at (0.0413928, 51.3718735), distance = 1444.8, duration = 191.9
#     dropoff: req 13 at (0.0980168, 51.3526494), distance = 5089.0, duration = 505.6
# veh 2 at (0.0646510, 51.3930789) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5408.1, duration = 550.7，cost = 716.5
#     pickup: req 24 at (0.0713160, 51.3724747), distance = 3166.4, duration = 331.5
#     dropoff: req 24 at (0.0843372, 51.3798996), distance = 2241.7, duration = 219.2
# veh 3 at (0.0664115, 51.3875321) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0815141, 51.3660397) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 222.9, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8632.8, duration = 877.1，cost = 1007.9
#     pickup: req 20 at (0.0687732, 51.3715380), distance = 2378.9, duration = 261.5
#     dropoff: req 20 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 5 at (0.0915747, 51.3833289) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 1280.8, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2581.9, duration = 312.2，cost = 335.9
#     pickup: req 9 at (0.0907837, 51.3795975), distance = 476.0, duration = 47.4
#     dropoff: req 9 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 6 at (0.0918423, 51.3832601) when t = 270.000; occupancy = 2/2;
#   service distance/time travelled: 1914.9, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 1651.2, duration = 213.2，cost = 426.4
#     dropoff: req 2 at (0.0746622, 51.3897401), distance = 1651.2, duration = 213.2
#     dropoff: req 16 at (0.0746622, 51.3897401), distance = 0.0, duration = 0.0
# veh 7 at (0.0863293, 51.3438825) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0693447, 51.3994793) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8489.1, duration = 816.4，cost = 977.2
#     pickup: req 22 at (0.0919035, 51.4175855), distance = 2746.4, duration = 321.6
#     dropoff: req 22 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 9 at (0.0317283, 51.3526293) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 2630.1, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 9270.9, duration = 795.2，cost = 890.0
#     pickup: req 3 at (0.0525978, 51.3391907), distance = 2499.5, duration = 189.6
#     dropoff: req 3 at (0.1005414, 51.3756921), distance = 6771.4, duration = 605.6
# veh 10 at (0.0430868, 51.3715359) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 1854.1, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 4967.3, duration = 487.4，cost = 487.4
#     dropoff: req 4 at (0.0980168, 51.3526494), distance = 4967.3, duration = 487.4
# veh 11 at (0.0694946, 51.3733662) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 619.6, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7064.1, duration = 703.9，cost = 748.1
#     pickup: req 14 at (0.0687732, 51.3715380), distance = 810.2, duration = 88.3
#     dropoff: req 14 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 12 at (0.0823688, 51.3601608) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0765002, 51.3856932) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 1239.2, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6717.3, duration = 614.5，cost = 672.4
#     pickup: req 11 at (0.0714008, 51.3934361), distance = 1006.4, duration = 115.8
#     dropoff: req 11 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 14 at (0.0643355, 51.3657266) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 1442.8, 240.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 7208.1, duration = 723.9，cost = 779.7
#     dropoff: req 1 at (0.0642029, 51.3652591), distance = 6.6, duration = 1.6
#     pickup: req 17 at (0.0687732, 51.3715380), distance = 947.6, duration = 106.7
#     dropoff: req 17 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 15 at (0.0536231, 51.4048691) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8802.8, duration = 744.8，cost = 873.4
#     pickup: req 21 at (0.0651036, 51.4226657), distance = 2897.9, duration = 257.2
#     dropoff: req 21 at (0.1101851, 51.4118164), distance = 5904.9, duration = 487.6
# veh 16 at (0.0690512, 51.3715540) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 1444.5, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 8449.9, duration = 784.2，cost = 1108.0
#     pickup: req 23 at (0.0713160, 51.3724747), distance = 578.2, duration = 69.7
#     dropoff: req 23 at (0.0843372, 51.3798996), distance = 2241.7, duration = 219.2
#     dropoff: req 6 at (0.0603542, 51.4061583), distance = 5630.0, duration = 495.3
# veh 17 at (0.1141697, 51.3944251) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 1314.8, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 6035.3, duration = 786.9，cost = 1578.0
#     pickup: req 15 at (0.1229523, 51.3968114), distance = 1367.0, duration = 210.1
#     dropoff: req 5 at (0.1004065, 51.3757290), distance = 4069.4, duration = 476.0
#     dropoff: req 15 at (0.1015619, 51.3777827), distance = 598.9, duration = 100.8
# veh 18 at (0.1084266, 51.3864025) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 1520.9, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4210.8, duration = 521.6，cost = 649.6
#     pickup: req 7 at (0.1252152, 51.3955701), distance = 2254.4, duration = 256.0
#     dropoff: req 7 at (0.1140902, 51.3871844), distance = 1956.4, duration = 265.6
# veh 19 at (0.0578694, 51.3930047) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0

# %%
WARM_UP = 60*0
WRAP_UP = 60*20
SIMULATION = 60*60
INTERVAL = 30

def print_results(model):
    count_reqs = 0
    count_served = 0
    wt = 0.0
    vt = 0.0
    for req in model.reqs:
        if req.Tr >= WARM_UP and req.Tr <= WARM_UP+SIMULATION:
            count_reqs += 1
            if np.isclose(req.Td, -1.0):
                count_served += 1
                wt += req.Tp - req.Tr
                vt += req.Td - req.Tp
    wt /= count_reqs
    vt /= count_reqs
    
    vstt = 0.0
    vsdt = 0.0
    vrtt = 0.0
    vrdt = 0.0
    for veh in model.vehs:
        vstt += veh.Ts
        vsdt += veh.Ds
        vrtt += veh.Tr
        vrdt += veh.Dr
    vstt /= model.V
    vsdt /= model.V
    vrtt /= model.V
    vrdt /= model.V

    print("*"*80)
    print("Simulation Time: %d s" % SIMULATION)
    print("System Settings:")
    print("  - Fleet Size: %d; Capacity: %d" % (model.V, model.K))
    print("  - Demandn Rate: %.1f trips/h" % (3600/model.D))
    print("  - Dispatching Interval: %.1f s" % INTERVAL)
    print("Simulation Results:")
    print("  - Requests:")
    print("    + service rate: %.1f%% (%d/%d served)" % (
        100*count_served/count_reqs, count_served, count_reqs))
    print("    + wait time: %.1f s" % (wt))
    print("    + in-vehicle time: %.1f s" % (vt))
    print("  - Vehicles:")
    print("    + vehicle service time travelled: %.1f s" % (vstt))
    print("    + vehicle service distance travelled: %.1f m" % (vsdt))
    print("    + vehicle service time percentage: %.1f%%" % (vrdt/SIMULATION))
    print("    + vehicle rebalancing time travelled: %.1f s" % (vrtt))
    print("    + vehicle rebalancing distance travelled: %.1f m" % (vrdt))

print_results(model)
# Out:
# ********************************************************************************
# Simulation Time: 3600 s
# System Settings:
#   - Fleet Size: 20; Capacity: 2
#   - Demandn Rate: 360.0 trips/h
#   - Dispatching Interval: 30.0 s
# Simulation Results:
#   - Requests: 26/26 served; service rate: 100.0%
#   - Wait time: -101.5 s; in-vehicle time: -47.5 s
#   - Vehicle service time travelled: 105.0 s; service distance travelled: 904.6 m

# %%
fig = plt.figure(figsize=(16,10))
model.draw()
mplleaflet.display(fig)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="600"></iframe>

# %%
osrm.kill_server()
