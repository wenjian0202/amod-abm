# %%
import time
import csv
import copy
import pandas as pd
import argparse
import numpy as np
import random
from multiprocessing import *
import mplleaflet
import matplotlib.pyplot as plt
from collections import deque

from lib.OsrmEngine import *
from lib.Agents import *
from lib.Demand import *

# %%
exe_loc = './osrm-backend-5.6.0/build/osrm-routed'
map_loc = './osrm-backend-5.6.0/greater-london-latest.osrm'

osrm = OsrmEngine(exe_loc, map_loc)
osrm.start_server()
osrm = OsrmEngine(exe_loc, map_loc)
osrm.start_server()
# Out:
# The routing server "http://0.0.0.0:5000" starts running
# The routing server "http://0.0.0.0:5000" is killed
# The routing server "http://0.0.0.0:5000" starts running

# %%
olng = 0.089653
olat = 51.373206
dlng = 0.089282
dlat = 51.350675

N = 1000
stime = time.time()
for i in range(N):
    o1 = random.uniform(-0.01, 0.01)
    o2 = random.uniform(-0.01, 0.01)
    d1 = random.uniform(-0.01, 0.01)
    d2 = random.uniform(-0.01, 0.01)
    out = osrm.get_routing(olng+o1, olat+o2, dlng+d1, dlat+d2)
etime = time.time()
print("Avarage running time per request: %.3fms" % ((etime-stime)*1000/N) )
# Out:
# Avarage running time per request: 5.108ms

# %%
import copy

B_W = 1.5
B_V = 1.0

class Veh(object):
    """ 
    Veh is a class for vehicles
    Attributes:
        id: sequential unique id
        T: system time at current state
        lat: current lngitude
        lng: current longtitude
        tlat: target (end of route) lngitude
        tlng: target (end of route) longtitude
        K: capacity
        n: number of passengers on board
        route: a list of legs
        t: total duration of the route
        d: total distance of the route
        c: total cost (generalized time) of the passegners
        Ds: accumulated service distance traveled
        Ts: accumulated service time traveled
        Dr: accumulated rebalancing distance traveled
        Tr: accumulated rebalancing time traveled
    """ 
    def __init__(self, id, K=4, lng=0.080444, lat=51.381263, T=0.0):
        self.id = id
        self.T = T
        self.lat = lat + np.random.normal(0.0, 0.015)
        self.lng = lng + np.random.normal(0.0, 0.020) 
        self.tlat = lat
        self.tlng = lng
        self.K = K
        self.n = 0
        self.route = deque([])
        self.t = 0.0
        self.d = 0.0
        self.c = 0.0
        self.Ds = 0.0
        self.Ts = 0.0
        self.Dr = 0.0
        self.Tr = 0.0
        
    def get_location(self):
        return (self.lng, self.lat)
    
    def get_target_location(self):
        return (self.tlng, self.tlat)
    
    def jump_to_location(self, lng, lat):
        self.lng = lng
        self.lat = lat
        
    def build_route(self, osrm, route):
        self.clear_route()
        for (rid, pod, tlng, tlat) in route:
            self.add_leg(osrm, rid, pod, tlng, tlat)
        self.update_cost()
        
    def clear_route(self):
        self.route.clear()
        self.d = 0.0
        self.t = 0.0
        self.c = 0.0
        self.tlng = self.lng
        self.tlat = self.lat
    
    def add_leg(self, osrm, rid, pod, tlng, tlat):
        out = osrm.get_routing(self.tlng, self.tlat, tlng, tlat)
        assert len(out['legs']) == 1
        leg = Leg(rid, pod, tlng, tlat, 
                  out['legs'][0]['distance'], out['legs'][0]['duration'], steps=[])
        for s in out['legs'][0]['steps']:
            step = Step(s['distance'], s['duration'], s['geometry']['coordinates'])
            leg.steps.append(step)
        assert len(step.geo) == 2
        assert step.geo[0] == step.geo[1]
        self.route.append(leg)
        self.tlng = leg.steps[-1].geo[1][0]
        self.tlat = leg.steps[-1].geo[1][1]
        self.d += leg.d
        self.t += leg.t
        
    def update_cost(self):
        c = 0.0
        t = 0.0
        n = self.n
        for leg in self.route:
            t += leg.t
            c += n * leg.t * B_V
            n += leg.pod
            c += t * B_W if leg.pod == 1 else 0
        self.c = c
        
    def move_to_time(self, T):
        dT = T - self.T
        if dT <= 0:
            return []
        done = []
        while dT > 0 and len(self.route) > 0:
            leg = self.route[0]
            if leg.t < dT:
                dT -= leg.t
                self.T += leg.t
                self.Ts += leg.t if leg.rid != -1 else 0
                self.Ds += leg.d if leg.rid != -1 else 0
                self.Tr += leg.t if leg.rid == -1 else 0
                self.Dr += leg.d if leg.rid == -1 else 0
                self.jump_to_location(leg.tlng, leg.tlat)
                self.n += leg.pod
                done.append( (leg.rid, leg.pod, self.T) )
                self.pop_leg()
            else:
                while dT > 0 and len(self.route[0].steps) > 0:
                    step = self.route[0].steps[0]
                    if step.t < dT:
                        dT -= step.t
                        self.Ts += step.t if leg.rid != -1 else 0
                        self.Ds += step.d if leg.rid != -1 else 0
                        self.Tr += step.t if leg.rid == -1 else 0
                        self.Dr += step.d if leg.rid == -1 else 0
                        self.pop_step()
                    else:
                        pct = dT / step.t
                        self.Ts += dT if leg.rid != -1 else 0
                        self.Ds += step.d * pct if leg.rid != -1 else 0
                        self.Tr += dT if leg.rid == -1 else 0
                        self.Dr += step.d * pct if leg.rid == -1 else 0
                        self.cut_step(pct)
                        self.jump_to_location(step.geo[0][0], step.geo[0][1])
                        self.T = T
                        return done
        assert dT > 0
        assert len(self.route) == 0 and self.n == 0
        assert np.isclose(self.d, 0.0)
        assert np.isclose(self.t, 0.0)
        self.T = T
        self.d = 0.0
        self.t = 0.0
        return done
        
    def pop_leg(self):
        leg = self.route.popleft()
        self.d -= leg.d
        self.t -= leg.t
        
    def pop_step(self):
        step = self.route[0].steps.popleft()
        self.t -= step.t
        self.d -= step.d
        self.route[0].t -= step.t
        self.route[0].d -= step.d
        
    def cut_step(self, pct):
        step = self.route[0].steps[0]
        dis = 0
        sega = step.geo[0]
        for segb in step.geo[1:]:
            dis += np.sqrt( (sega[0] - segb[0])**2 + (sega[1] - segb[1])**2)
            sega = segb
        dis_ = 0
        sega = step.geo[0]
        for segb in step.geo[1:]:
            _dis = np.sqrt( (sega[0] - segb[0])**2 + (sega[1] - segb[1])**2)
            dis_ += _dis
            if dis_ / dis > pct:
                break
            sega = segb
        while step.geo[0] != sega:
            step.geo.pop(0)
        _pct = (pct * dis - dis_ + _dis) / _dis
        
        step.geo[0][0] = sega[0] + _pct * (segb[0] - sega[0])
        step.geo[0][1] = sega[1] + _pct * (segb[1] - sega[1])
        
        self.t -= step.t * pct
        self.d -= step.d * pct
        self.route[0].t -= step.t * pct
        self.route[0].d -= step.d * pct
        self.route[0].steps[0].t -= step.t * pct
        self.route[0].steps[0].d -= step.d * pct  
    
    def draw(self):
        plt.plot(self.lng, self.lat, 'b', marker='o')
        count = 0
        for leg in self.route:
            count += 1
            plt.plot(leg.tlng, leg.tlat, 'b', 
                     marker='+' if leg.pod == 1 else 'x' if leg.pod == -1 else '.')
            for step in leg.steps:
                geo = np.transpose( step.geo )
                plt.plot(geo[0], geo[1], 'b', linestyle='-' if count<=1 else '--')

                        
    def __str__(self):
        str =  "veh %d at (%.7f, %.7f) when t = %.3f; occupancy = %d/%d;" % (
            self.id, self.lng, self.lat, self.T, self.n, self.K)
        str += "\n  service distance/time travelled: %.1f, %.1f; rebalancing distance/time travelled: %.1f, %.1f" % (
            self.Ds, self.Ts, self.Dr, self.Tr)
        str += "\n  has %d leg(s), distance = %.1f, duration = %.1f，cost = %.1f" % (
            len(self.route), self.d, self.t, self.c)
        for leg in self.route:
            str += "\n    %s: req %d at (%.7f, %.7f), distance = %.1f, duration = %.1f" % (
                "pickup" if leg.pod == 1 else "dropoff" if leg.pod == -1 else "rebalancing",
                leg.rid, leg.tlng, leg.tlat, leg.d, leg.t)
        return str
    

class Req(object):
    """ 
    Req is a class for requests
    Attributes:
        id: sequential unique id
        Tr: request time
        olat: origin lngitude
        olng: origin longtitude
        dlng: destination longtitude
        dlat: destination lngitude
        Clp: constraint - latest pickup
        Cld: constraint - latest dropoff
        Tp: pickup time
        Td: dropoff time
    """
    def __init__(self, osrm, id, Tr, olat=51.374282, olng=0.115662, dlat=51.350675, dlng=0.089282):
        self.id = id
        self.Tr = Tr
        self.olat = olat
        self.olng = olng
        self.dlat = dlat
        self.dlng = dlng
        self.Clp = Tr + 480
        self.Cld = self.Clp + 2 * osrm.get_duration(olng, olat, dlng, dlat)
        self.Tp = -1.0
        self.Td = -1.0
    
    def get_origin(self):
        return (self.olng, self.olat)
    
    def get_destination(self):
        return (self.dlng, self.dlat)
    
    def draw(self):
        plt.plot(self.olng, self.olat, 'r', marker='+')
        plt.plot(self.dlng, self.dlat, 'r', marker='x')
        plt.plot([self.olng, self.dlng], [self.olat, self.dlat], 'r', linestyle='--', dashes=(0.5,1.5))
    
    def __str__(self):
        str = "req %d from (%.7f, %.7f) to (%.7f, %.7f) at t = %.3f" % (
            self.id, self.olng, self.olat, self.dlng, self.dlat, self.Tr)
        str += "\n  latest pickup at t = %.3f, latest dropoff at t = %.3f" % ( self.Clp, self.Cld)
        str += "\n  pickup at t = %.3f, dropoff at t = %.3f" % ( self.Tp, self.Td)
        return str
    

class Model(object):
    """
    Model is the class for the AMoD system
    Attributes:
        T: system time at current state
        D: average arrival interval (sec)
        demand: demand matrix
        V: number of vehicles
        K: capacity of vehicles
        vehs: the list of vehicles
        N: number of requests
        reqs: the list of requests
        queue: requests in the queue
    """ 
    def __init__(self, D, demand, V=2, K=4):
        self.T = 0.0
        self.D = D
        self.demand = demand
        self.V = V
        self.K = K
        self.vehs = []
        for i in range(V):
            self.vehs.append(Veh(i, K=K))
        self.N = 0
        self.reqs = []
        self.queue = deque([])
        
    def generate_request(self, osrm):
        dt = self.D * np.random.exponential()
        rand = np.random.rand()
        for d in demand:
            if d[4] > rand:
                req = Req(osrm, 
                          0 if self.N == 0 else self.reqs[-1].id+1,
                          dt if self.N == 0 else self.reqs[-1].Tr+dt,
                          d[0], d[1], d[2], d[3])
                break
        self.N += 1
        return req
        
    def generate_requests_to_time(self, osrm, T):
        if self.N == 0:
            req = self.generate_request(osrm)
            self.reqs.append(req)
        while self.reqs[-1].Tr <= T:
            req = self.generate_request(osrm)
            self.queue.append(self.reqs[-1])
            self.reqs.append(req)
        assert self.N == len(self.reqs)
        
    def dispatch_at_time(self, osrm, T):
        self.T = T
        for v in self.vehs:
            done = v.move_to_time(T)
            for (rid, pod, t) in done:
                if pod == 1:
                    self.reqs[rid].Tp = t
                elif pod == -1:
                    self.reqs[rid].Td = t
            v.update_cost()
        self.generate_requests_to_time(osrm, T)
        print(self)
        self.assign(osrm)
        for v in self.vehs:
            print(v)
        
    def assign(self, osrm):
        l = len(self.queue)
        for i in range(l):
            req = self.queue.popleft()
            if not self.insert_heuristics(osrm, req):
                self.queue.append(req)
        
    def insert_heuristics(self, osrm, req):
        dc = np.inf
        v_ = None
        r_ = None
        viol = None
        for v in self.vehs:
            route = []
            for leg in v.route:
                route.append( (leg.rid, leg.pod, leg.tlng, leg.tlat) )
            l = len(route)
            c = v.c
            for i in range(l+1):
                for j in range(i+1, l+2):
                    route.insert(i, (req.id, 1, req.olng, req.olat) )
                    route.insert(j, (req.id, -1, req.dlng, req.dlat) )
                    flag, dc_, viol = self.test_constraints_get_cost(osrm, route, v, dc)
                    if flag:
                        dc = dc_
                        v_ = v
                        r_ = copy.deepcopy(route)
                    elif "late_pickup" in viol or "late_dropoff" in viol or "over_capacity" in viol:
                        break
                    route.pop(j)
                    route.pop(i)
                if "late_pickup" in viol:
                    break
        if v_ != None:
            v_.build_route(osrm, r_)
            return True
        else:
            return False
    
    def test_constraints_get_cost(self, osrm, route, v, dc):
        C = v.c + dc
        c = 0.0
        t = 0.0
        n = v.n
        T = v.T
        K = v.K
        lng = v.lng
        lat = v.lat
        for (rid, pod, tlng, tlat) in route:
            dt = osrm.get_duration(lng, lat, tlng, tlat)
            t += dt
            if pod == 1 and T + t > self.reqs[rid].Clp:
                return False, None, ["late_pickup"]
            elif pod == -1 and T + t > self.reqs[rid].Cld:
                return False, None, ["late_dropoff"]
            c += n * dt * B_V
            n += pod
            if n > K:
                return False, None, ["over_capacity"]
            c += t * B_W if pod == 1 else 0
            if c > C:
                return False, None, ["high_cost"]
            lng = tlng
            lat = tlat
        assert c-v.c >= 0
        return True, c-v.c, []
    
    def draw(self):
        for v in self.vehs:
            v.draw()
        for r in self.queue:
            r.draw()
        
    def __str__(self):
        str = "AMoD system: %d vehicles of capacity %d; %.1f trips/h" % (self.V, self.K, 3600/self.D)
        str += "\n  at t = %.3f, %d requests, in which %d in queue" % ( self.T, self.N-1, len(self.queue) )
        for r in self.queue:
            str += "\n" + r.__str__()
        return str

# %%
model = Model(10, demand, V=20, K=2)
T = 0

# %%
stime = time.time()
for T in range(0,300,30):
    model.dispatch_at_time(osrm, T)
etime = time.time()
runtime = etime - stime
# Out:
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 0.000, 0 requests, in which 0 in queue
# veh 0 at (0.0904712, 51.3973760) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 1 at (0.1156647, 51.3682961) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0670267, 51.3725361) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0666369, 51.3739157) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0546164, 51.3775184) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0901024, 51.4051411) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0672325, 51.3868770) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0815251, 51.3957296) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0552566, 51.3900175) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 9 at (0.1074539, 51.3538950) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0766710, 51.3828411) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 11 at (0.0839921, 51.3631461) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0572987, 51.3671733) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0567602, 51.3504013) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0919841, 51.3617681) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 15 at (0.0635456, 51.3590371) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0707517, 51.3730534) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 17 at (0.0461971, 51.4038834) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 18 at (0.0958239, 51.3851427) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 19 at (0.0725948, 51.3484262) when t = 0.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 30.000, 3 requests, in which 3 in queue
# req 0 from (0.0919035, 51.4175855) to (0.0712996, 51.3933688) at t = 1.117
#   latest pickup at t = 481.117, latest dropoff at t = 1470.517
#   pickup at t = -1.000, dropoff at t = -1.000
# req 1 from (0.0420004, 51.3946469) to (0.0452234, 51.3999896) at t = 17.268
#   latest pickup at t = 497.268, latest dropoff at t = 707.868
#   pickup at t = -1.000, dropoff at t = -1.000
# req 2 from (0.0687732, 51.3715380) to (0.0603542, 51.4061583) at t = 17.633
#   latest pickup at t = 497.633, latest dropoff at t = 1728.833
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0904712, 51.3973760) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 9589.9, duration = 835.5，cost = 1005.8
#     pickup: req 0 at (0.0919035, 51.4175855), distance = 3847.2, duration = 340.7
#     dropoff: req 0 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 1 at (0.1156647, 51.3682961) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0670267, 51.3725361) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0666369, 51.3739157) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0546164, 51.3775184) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0901024, 51.4051411) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0672325, 51.3868770) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0815251, 51.3957296) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 8 at (0.0552566, 51.3900175) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2463.0, duration = 277.6，cost = 363.8
#     pickup: req 1 at (0.0420004, 51.3946469), distance = 1577.4, duration = 172.3
#     dropoff: req 1 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
# veh 9 at (0.1074539, 51.3538950) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0766710, 51.3828411) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 11 at (0.0839921, 51.3631461) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0572987, 51.3671733) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0567602, 51.3504013) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0919841, 51.3617681) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 15 at (0.0635456, 51.3590371) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0707517, 51.3730534) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6919.5, duration = 687.9，cost = 724.0
#     pickup: req 2 at (0.0687732, 51.3715380), distance = 665.6, duration = 72.3
#     dropoff: req 2 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 17 at (0.0461971, 51.4038834) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 18 at (0.0958239, 51.3851427) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 19 at (0.0725948, 51.3484262) when t = 30.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 60.000, 8 requests, in which 5 in queue
# req 3 from (0.1058691, 51.4118283) to (0.0950427, 51.3625064) at t = 37.283
#   latest pickup at t = 517.283, latest dropoff at t = 1986.083
#   pickup at t = -1.000, dropoff at t = -1.000
# req 4 from (0.1176802, 51.3898180) to (0.1004065, 51.3757290) at t = 39.798
#   latest pickup at t = 519.798, latest dropoff at t = 1149.798
#   pickup at t = -1.000, dropoff at t = -1.000
# req 5 from (0.0714008, 51.3934361) to (0.0918767, 51.4176560) at t = 42.988
#   latest pickup at t = 522.988, latest dropoff at t = 1520.388
#   pickup at t = -1.000, dropoff at t = -1.000
# req 6 from (0.0713160, 51.3724747) to (0.0843372, 51.3798996) at t = 44.308
#   latest pickup at t = 524.308, latest dropoff at t = 962.508
#   pickup at t = -1.000, dropoff at t = -1.000
# req 7 from (0.1141772, 51.3978578) to (0.1047756, 51.4245615) at t = 49.071
#   latest pickup at t = 529.071, latest dropoff at t = 1113.671
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0885215, 51.3962099) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 197.2, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 9392.7, duration = 805.5，cost = 960.8
#     pickup: req 0 at (0.0919035, 51.4175855), distance = 3650.0, duration = 310.7
#     dropoff: req 0 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 1 at (0.1156647, 51.3682961) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7359.6, duration = 608.5，cost = 766.6
#     pickup: req 7 at (0.1141772, 51.3978578), distance = 3667.3, duration = 316.2
#     dropoff: req 7 at (0.1047756, 51.4245615), distance = 3692.3, duration = 292.3
# veh 2 at (0.0670267, 51.3725361) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2661.1, duration = 260.4，cost = 281.0
#     pickup: req 6 at (0.0713160, 51.3724747), distance = 419.4, duration = 41.2
#     dropoff: req 6 at (0.0843372, 51.3798996), distance = 2241.7, duration = 219.2
# veh 3 at (0.0666369, 51.3739157) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0546164, 51.3775184) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0901024, 51.4051411) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8941.8, duration = 983.5，cost = 1108.0
#     pickup: req 3 at (0.1058691, 51.4118283), distance = 2070.7, duration = 249.1
#     dropoff: req 3 at (0.0950427, 51.3625064), distance = 6871.1, duration = 734.4
# veh 6 at (0.0672325, 51.3868770) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0815251, 51.3957296) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6612.2, duration = 635.0，cost = 703.1
#     pickup: req 5 at (0.0714008, 51.3934361), distance = 901.3, duration = 136.3
#     dropoff: req 5 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 8 at (0.0529936, 51.3903657) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 235.4, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2227.6, duration = 247.6，cost = 318.8
#     pickup: req 1 at (0.0420004, 51.3946469), distance = 1342.0, duration = 142.3
#     dropoff: req 1 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
# veh 9 at (0.1074539, 51.3538950) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0766710, 51.3828411) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 11 at (0.0839921, 51.3631461) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 12 at (0.0572987, 51.3671733) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0567602, 51.3504013) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0919841, 51.3617681) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 15 at (0.0635456, 51.3590371) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0720747, 51.3707485) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 295.6, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6623.9, duration = 657.9，cost = 679.1
#     pickup: req 2 at (0.0687732, 51.3715380), distance = 370.0, duration = 42.3
#     dropoff: req 2 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 17 at (0.0461971, 51.4038834) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 18 at (0.0958239, 51.3851427) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4858.2, duration = 600.9，cost = 743.8
#     pickup: req 4 at (0.1176802, 51.3898180), distance = 2396.1, duration = 285.9
#     dropoff: req 4 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 19 at (0.0725948, 51.3484262) when t = 60.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 90.000, 11 requests, in which 3 in queue
# req 8 from (0.0885501, 51.3657524) to (0.1070611, 51.3758154) at t = 67.902
#   latest pickup at t = 547.902, latest dropoff at t = 1230.502
#   pickup at t = -1.000, dropoff at t = -1.000
# req 9 from (0.0933248, 51.3928668) to (0.0894257, 51.4023735) at t = 73.535
#   latest pickup at t = 553.535, latest dropoff at t = 857.935
#   pickup at t = -1.000, dropoff at t = -1.000
# req 10 from (0.0420004, 51.3946469) to (0.0452234, 51.3999896) at t = 74.356
#   latest pickup at t = 554.356, latest dropoff at t = 764.956
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0874099, 51.3983727) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 544.7, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 9045.2, duration = 775.5，cost = 915.8
#     pickup: req 0 at (0.0919035, 51.4175855), distance = 3302.5, duration = 280.7
#     dropoff: req 0 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 1 at (0.1143825, 51.3705696) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 187.4, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7172.2, duration = 578.5，cost = 721.6
#     pickup: req 7 at (0.1141772, 51.3978578), distance = 3479.9, duration = 286.2
#     dropoff: req 7 at (0.1047756, 51.4245615), distance = 3692.3, duration = 292.3
# veh 2 at (0.0708395, 51.3734403) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 298.5, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2362.6, duration = 230.4，cost = 236.0
#     pickup: req 6 at (0.0713160, 51.3724747), distance = 120.9, duration = 11.2
#     dropoff: req 6 at (0.0843372, 51.3798996), distance = 2241.7, duration = 219.2
# veh 3 at (0.0666369, 51.3739157) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0546164, 51.3775184) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0910837, 51.4056626) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 169.0, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8772.8, duration = 953.5，cost = 1063.0
#     pickup: req 3 at (0.1058691, 51.4118283), distance = 1901.7, duration = 219.1
#     dropoff: req 3 at (0.0950427, 51.3625064), distance = 6871.1, duration = 734.4
# veh 6 at (0.0672325, 51.3868770) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0789876, 51.3945686) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 207.7, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6404.5, duration = 605.0，cost = 658.1
#     pickup: req 5 at (0.0714008, 51.3934361), distance = 693.6, duration = 106.3
#     dropoff: req 5 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 8 at (0.0487172, 51.3894197) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 550.8, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 4 leg(s), distance = 1911.9, duration = 218.5，cost = 550.2
#     pickup: req 1 at (0.0420004, 51.3946469), distance = 1026.0, duration = 113.2
#     pickup: req 10 at (0.0420004, 51.3946469), distance = 0.0, duration = 0.0
#     dropoff: req 1 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
#     dropoff: req 10 at (0.0452234, 51.3999896), distance = 0.3, duration = 0.0
# veh 9 at (0.1074539, 51.3538950) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0766710, 51.3828411) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3884.4, duration = 398.0，cost = 520.9
#     pickup: req 9 at (0.0933248, 51.3928668), distance = 2261.8, duration = 245.8
#     dropoff: req 9 at (0.0894257, 51.4023735), distance = 1622.6, duration = 152.2
# veh 11 at (0.0839921, 51.3631461) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4132.8, duration = 425.2，cost = 467.2
#     pickup: req 8 at (0.0885501, 51.3657524), distance = 746.2, duration = 83.9
#     dropoff: req 8 at (0.1070611, 51.3758154), distance = 3386.6, duration = 341.3
# veh 12 at (0.0572987, 51.3671733) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0567602, 51.3504013) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0919841, 51.3617681) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 15 at (0.0635456, 51.3590371) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0696505, 51.3709280) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 549.4, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6370.1, duration = 627.9，cost = 634.1
#     pickup: req 2 at (0.0687732, 51.3715380), distance = 116.2, duration = 12.3
#     dropoff: req 2 at (0.0603542, 51.4061583), distance = 6253.9, duration = 615.6
# veh 17 at (0.0461971, 51.4038834) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 18 at (0.0967242, 51.3831028) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 170.5, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4687.7, duration = 570.9，cost = 698.9
#     pickup: req 4 at (0.1176802, 51.3898180), distance = 2225.6, duration = 255.9
#     dropoff: req 4 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 19 at (0.0725948, 51.3484262) when t = 90.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 120.000, 12 requests, in which 1 in queue
# req 11 from (0.0919035, 51.4175855) to (0.0712996, 51.3933688) at t = 91.115
#   latest pickup at t = 571.115, latest dropoff at t = 1560.515
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0864153, 51.4023810) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 996.6, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8593.3, duration = 745.5，cost = 870.8
#     pickup: req 0 at (0.0919035, 51.4175855), distance = 2850.6, duration = 250.7
#     dropoff: req 0 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 1 at (0.1108394, 51.3720257) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 481.9, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6877.7, duration = 548.5，cost = 676.6
#     pickup: req 7 at (0.1141772, 51.3978578), distance = 3185.4, duration = 256.2
#     dropoff: req 7 at (0.1047756, 51.4245615), distance = 3692.3, duration = 292.3
# veh 2 at (0.0716562, 51.3734211) when t = 120.000; occupancy = 1/2;
#   service distance/time travelled: 585.5, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 2075.6, duration = 200.4，cost = 200.4
#     dropoff: req 6 at (0.0843372, 51.3798996), distance = 2075.6, duration = 200.4
# veh 3 at (0.0666369, 51.3739157) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0546164, 51.3775184) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0942372, 51.4061669) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 436.8, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8505.0, duration = 923.5，cost = 1018.0
#     pickup: req 3 at (0.1058691, 51.4118283), distance = 1633.9, duration = 189.1
#     dropoff: req 3 at (0.0950427, 51.3625064), distance = 6871.1, duration = 734.4
# veh 6 at (0.0672325, 51.3868770) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0763767, 51.3952299) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 404.1, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6208.1, duration = 575.0，cost = 613.1
#     pickup: req 5 at (0.0714008, 51.3934361), distance = 497.2, duration = 76.3
#     dropoff: req 5 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 8 at (0.0446347, 51.3899637) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 855.7, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 4 leg(s), distance = 1607.0, duration = 188.5，cost = 460.2
#     pickup: req 1 at (0.0420004, 51.3946469), distance = 721.1, duration = 83.2
#     pickup: req 10 at (0.0420004, 51.3946469), distance = 0.0, duration = 0.0
#     dropoff: req 1 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
#     dropoff: req 10 at (0.0452234, 51.3999896), distance = 0.3, duration = 0.0
# veh 9 at (0.1074539, 51.3538950) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0764810, 51.3854332) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 317.3, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3567.1, duration = 368.0，cost = 475.9
#     pickup: req 9 at (0.0933248, 51.3928668), distance = 1944.5, duration = 215.8
#     dropoff: req 9 at (0.0894257, 51.4023735), distance = 1622.6, duration = 152.2
# veh 11 at (0.0834614, 51.3645605) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 241.3, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3891.5, duration = 395.2，cost = 422.2
#     pickup: req 8 at (0.0885501, 51.3657524), distance = 504.9, duration = 53.9
#     dropoff: req 8 at (0.1070611, 51.3758154), distance = 3386.6, duration = 341.3
# veh 12 at (0.0572987, 51.3671733) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0567602, 51.3504013) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0919841, 51.3617681) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 15 at (0.0635456, 51.3590371) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0697857, 51.3707114) when t = 120.000; occupancy = 1/2;
#   service distance/time travelled: 808.2, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 6111.3, duration = 597.9，cost = 597.9
#     dropoff: req 2 at (0.0603542, 51.4061583), distance = 6111.3, duration = 597.9
# veh 17 at (0.0461971, 51.4038834) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 10009.6, duration = 858.4，cost = 1040.2
#     pickup: req 11 at (0.0919035, 51.4175855), distance = 4266.9, duration = 363.6
#     dropoff: req 11 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 18 at (0.1008274, 51.3825173) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 474.0, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4384.2, duration = 540.9，cost = 653.9
#     pickup: req 4 at (0.1176802, 51.3898180), distance = 1922.1, duration = 225.9
#     dropoff: req 4 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 19 at (0.0725948, 51.3484262) when t = 120.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 150.000, 14 requests, in which 2 in queue
# req 12 from (0.0420004, 51.3946469) to (0.0452234, 51.3999896) at t = 122.890
#   latest pickup at t = 602.890, latest dropoff at t = 813.490
#   pickup at t = -1.000, dropoff at t = -1.000
# req 13 from (0.0628968, 51.3712046) to (0.0739150, 51.3585900) at t = 143.362
#   latest pickup at t = 623.362, latest dropoff at t = 1119.362
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0838258, 51.4049875) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 1326.5, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8263.4, duration = 715.5，cost = 825.8
#     pickup: req 0 at (0.0919035, 51.4175855), distance = 2520.7, duration = 220.7
#     dropoff: req 0 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 1 at (0.1091619, 51.3742668) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 847.0, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6512.6, duration = 518.5，cost = 631.6
#     pickup: req 7 at (0.1141772, 51.3978578), distance = 2820.3, duration = 226.2
#     dropoff: req 7 at (0.1047756, 51.4245615), distance = 3692.3, duration = 292.3
# veh 2 at (0.0755309, 51.3733115) when t = 150.000; occupancy = 1/2;
#   service distance/time travelled: 854.8, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 1806.3, duration = 170.4，cost = 170.4
#     dropoff: req 6 at (0.0843372, 51.3798996), distance = 1806.3, duration = 170.4
# veh 3 at (0.0666369, 51.3739157) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2779.5, duration = 330.8，cost = 372.2
#     pickup: req 13 at (0.0628968, 51.3712046), distance = 586.6, duration = 82.8
#     dropoff: req 13 at (0.0739150, 51.3585900), distance = 2192.9, duration = 248.0
# veh 4 at (0.0546164, 51.3775184) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0980563, 51.4082473) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 769.8, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8172.0, duration = 893.5，cost = 973.0
#     pickup: req 3 at (0.1058691, 51.4118283), distance = 1300.9, duration = 159.1
#     dropoff: req 3 at (0.0950427, 51.3625064), distance = 6871.1, duration = 734.4
# veh 6 at (0.0672325, 51.3868770) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3468.2, duration = 381.9，cost = 520.2
#     pickup: req 12 at (0.0420004, 51.3946469), distance = 2582.6, duration = 276.6
#     dropoff: req 12 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
# veh 7 at (0.0739099, 51.3954213) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 600.1, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6012.1, duration = 545.0，cost = 568.1
#     pickup: req 5 at (0.0714008, 51.3934361), distance = 301.2, duration = 46.3
#     dropoff: req 5 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 8 at (0.0450996, 51.3925691) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 1149.4, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 4 leg(s), distance = 1313.4, duration = 158.5，cost = 370.2
#     pickup: req 1 at (0.0420004, 51.3946469), distance = 427.5, duration = 53.2
#     pickup: req 10 at (0.0420004, 51.3946469), distance = 0.0, duration = 0.0
#     dropoff: req 1 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
#     dropoff: req 10 at (0.0452234, 51.3999896), distance = 0.3, duration = 0.0
# veh 9 at (0.1074539, 51.3538950) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0781386, 51.3879302) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 629.0, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3255.4, duration = 338.0，cost = 430.9
#     pickup: req 9 at (0.0933248, 51.3928668), distance = 1632.8, duration = 185.8
#     dropoff: req 9 at (0.0894257, 51.4023735), distance = 1622.6, duration = 152.2
# veh 11 at (0.0859625, 51.3660968) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 537.8, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3595.0, duration = 365.2，cost = 377.2
#     pickup: req 8 at (0.0885501, 51.3657524), distance = 208.4, duration = 23.9
#     dropoff: req 8 at (0.1070611, 51.3758154), distance = 3386.6, duration = 341.3
# veh 12 at (0.0572987, 51.3671733) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 13 at (0.0567602, 51.3504013) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0919841, 51.3617681) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 15 at (0.0635456, 51.3590371) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0720609, 51.3707328) when t = 150.000; occupancy = 1/2;
#   service distance/time travelled: 1033.4, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 5886.1, duration = 567.9，cost = 567.9
#     dropoff: req 2 at (0.0603542, 51.4061583), distance = 5886.1, duration = 567.9
# veh 17 at (0.0435520, 51.4040035) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 190.4, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 9819.2, duration = 828.4，cost = 995.2
#     pickup: req 11 at (0.0919035, 51.4175855), distance = 4076.5, duration = 333.6
#     dropoff: req 11 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 18 at (0.1050295, 51.3823440) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 777.6, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4080.6, duration = 510.9，cost = 608.9
#     pickup: req 4 at (0.1176802, 51.3898180), distance = 1618.5, duration = 195.9
#     dropoff: req 4 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 19 at (0.0725948, 51.3484262) when t = 150.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 180.000, 16 requests, in which 2 in queue
# req 14 from (0.0628968, 51.3712046) to (0.0739150, 51.3585900) at t = 150.572
#   latest pickup at t = 630.572, latest dropoff at t = 1126.572
#   pickup at t = -1.000, dropoff at t = -1.000
# req 15 from (0.1141772, 51.3978578) to (0.1047756, 51.4245615) at t = 154.966
#   latest pickup at t = 634.966, latest dropoff at t = 1219.566
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0817249, 51.4079998) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 1656.4, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7933.5, duration = 685.5，cost = 780.8
#     pickup: req 0 at (0.0919035, 51.4175855), distance = 2190.8, duration = 190.7
#     dropoff: req 0 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 1 at (0.1088720, 51.3779929) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 1257.4, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6102.2, duration = 488.5，cost = 586.6
#     pickup: req 7 at (0.1141772, 51.3978578), distance = 2409.9, duration = 196.2
#     dropoff: req 7 at (0.1047756, 51.4245615), distance = 3692.3, duration = 292.3
# veh 2 at (0.0764933, 51.3757244) when t = 180.000; occupancy = 1/2;
#   service distance/time travelled: 1177.5, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 1483.6, duration = 140.4，cost = 140.4
#     dropoff: req 6 at (0.0843372, 51.3798996), distance = 1483.6, duration = 140.4
# veh 3 at (0.0655594, 51.3731763) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 143.7, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2635.8, duration = 300.8，cost = 327.2
#     pickup: req 13 at (0.0628968, 51.3712046), distance = 442.9, duration = 52.8
#     dropoff: req 13 at (0.0739150, 51.3585900), distance = 2192.9, duration = 248.0
# veh 4 at (0.0546164, 51.3775184) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.1023649, 51.4086849) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 1097.9, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7843.9, duration = 863.5，cost = 928.0
#     pickup: req 3 at (0.1058691, 51.4118283), distance = 972.8, duration = 129.1
#     dropoff: req 3 at (0.0950427, 51.3625064), distance = 6871.1, duration = 734.4
# veh 6 at (0.0673847, 51.3882744) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 186.1, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3282.1, duration = 351.9，cost = 475.2
#     pickup: req 12 at (0.0420004, 51.3946469), distance = 2396.5, duration = 246.6
#     dropoff: req 12 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
# veh 7 at (0.0723737, 51.3939644) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 794.0, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5818.2, duration = 515.0，cost = 523.1
#     pickup: req 5 at (0.0714008, 51.3934361), distance = 107.3, duration = 16.3
#     dropoff: req 5 at (0.0918767, 51.4176560), distance = 5710.9, duration = 498.7
# veh 8 at (0.0443013, 51.3943929) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 1415.3, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 4 leg(s), distance = 1047.4, duration = 128.5，cost = 280.2
#     pickup: req 1 at (0.0420004, 51.3946469), distance = 161.5, duration = 23.2
#     pickup: req 10 at (0.0420004, 51.3946469), distance = 0.0, duration = 0.0
#     dropoff: req 1 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
#     dropoff: req 10 at (0.0452234, 51.3999896), distance = 0.3, duration = 0.0
# veh 9 at (0.1074539, 51.3538950) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0798171, 51.3905096) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 940.6, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2943.8, duration = 308.0，cost = 385.9
#     pickup: req 9 at (0.0933248, 51.3928668), distance = 1321.2, duration = 155.8
#     dropoff: req 9 at (0.0894257, 51.4023735), distance = 1622.6, duration = 152.2
# veh 11 at (0.0876038, 51.3659318) when t = 180.000; occupancy = 1/2;
#   service distance/time travelled: 804.0, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 3328.8, duration = 335.2，cost = 335.2
#     dropoff: req 8 at (0.1070611, 51.3758154), distance = 3328.8, duration = 335.2
# veh 12 at (0.0572987, 51.3671733) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2890.4, duration = 337.5，cost = 382.2
#     pickup: req 14 at (0.0628968, 51.3712046), distance = 697.5, duration = 89.5
#     dropoff: req 14 at (0.0739150, 51.3585900), distance = 2192.9, duration = 248.0
# veh 13 at (0.0567602, 51.3504013) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0919841, 51.3617681) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 15 at (0.0635456, 51.3590371) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 16 at (0.0743645, 51.3728994) when t = 180.000; occupancy = 1/2;
#   service distance/time travelled: 1327.5, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 5592.0, duration = 537.9，cost = 537.9
#     dropoff: req 2 at (0.0603542, 51.4061583), distance = 5592.0, duration = 537.9
# veh 17 at (0.0426644, 51.4053584) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 394.0, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 9615.6, duration = 798.4，cost = 950.2
#     pickup: req 11 at (0.0919035, 51.4175855), distance = 3872.9, duration = 303.6
#     dropoff: req 11 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 18 at (0.1080897, 51.3827996) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 1059.2, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3799.0, duration = 480.9，cost = 563.9
#     pickup: req 4 at (0.1176802, 51.3898180), distance = 1336.9, duration = 165.9
#     dropoff: req 4 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 19 at (0.0725948, 51.3484262) when t = 180.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 210.000, 20 requests, in which 5 in queue
# req 15 from (0.1141772, 51.3978578) to (0.1047756, 51.4245615) at t = 154.966
#   latest pickup at t = 634.966, latest dropoff at t = 1219.566
#   pickup at t = -1.000, dropoff at t = -1.000
# req 16 from (0.0919035, 51.4175855) to (0.0712996, 51.3933688) at t = 191.349
#   latest pickup at t = 671.349, latest dropoff at t = 1660.749
#   pickup at t = -1.000, dropoff at t = -1.000
# req 17 from (0.0794164, 51.3867846) to (0.0751755, 51.3735478) at t = 192.406
#   latest pickup at t = 672.406, latest dropoff at t = 1094.806
#   pickup at t = -1.000, dropoff at t = -1.000
# req 18 from (0.0907837, 51.3795975) to (0.0746622, 51.3897401) at t = 201.866
#   latest pickup at t = 681.866, latest dropoff at t = 1211.466
#   pickup at t = -1.000, dropoff at t = -1.000
# req 19 from (0.0794164, 51.3867846) to (0.0751755, 51.3735478) at t = 206.940
#   latest pickup at t = 686.940, latest dropoff at t = 1109.340
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0786251, 51.4099103) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 1986.4, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7603.5, duration = 655.5，cost = 735.9
#     pickup: req 0 at (0.0919035, 51.4175855), distance = 1860.8, duration = 160.7
#     dropoff: req 0 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 1 at (0.1081181, 51.3816189) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 1667.8, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5691.8, duration = 458.5，cost = 541.6
#     pickup: req 7 at (0.1141772, 51.3978578), distance = 1999.5, duration = 166.2
#     dropoff: req 7 at (0.1047756, 51.4245615), distance = 3692.3, duration = 292.3
# veh 2 at (0.0785095, 51.3782753) when t = 210.000; occupancy = 1/2;
#   service distance/time travelled: 1509.6, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 4664.3, duration = 511.9，cost = 773.2
#     dropoff: req 6 at (0.0843372, 51.3798996), distance = 1155.3, duration = 111.0
#     pickup: req 17 at (0.0794164, 51.3867846), distance = 1465.3, duration = 189.7
#     dropoff: req 17 at (0.0751755, 51.3735478), distance = 2043.7, duration = 211.2
# veh 3 at (0.0650728, 51.3718036) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 373.6, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2405.9, duration = 270.8，cost = 282.2
#     pickup: req 13 at (0.0628968, 51.3712046), distance = 213.0, duration = 22.8
#     dropoff: req 13 at (0.0739150, 51.3585900), distance = 2192.9, duration = 248.0
# veh 4 at (0.0546164, 51.3775184) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.1064794, 51.4088443) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 1383.9, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7557.9, duration = 833.5，cost = 883.0
#     pickup: req 3 at (0.1058691, 51.4118283), distance = 686.8, duration = 99.1
#     dropoff: req 3 at (0.0950427, 51.3625064), distance = 6871.1, duration = 734.4
# veh 6 at (0.0638342, 51.3886452) when t = 210.000; occupancy = 0/2;
#   service distance/time travelled: 445.9, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3022.3, duration = 321.9，cost = 430.2
#     pickup: req 12 at (0.0420004, 51.3946469), distance = 2136.7, duration = 216.6
# ...
# veh 1 at (0.1077464, 51.3851831) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 2072.7, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5286.9, duration = 428.5，cost = 496.6
#     pickup: req 7 at (0.1141772, 51.3978578), distance = 1594.6, duration = 136.2
#     dropoff: req 7 at (0.1047756, 51.4245615), distance = 3692.3, duration = 292.3
# veh 2 at (0.0801624, 51.3810605) when t = 240.000; occupancy = 1/2;
#   service distance/time travelled: 1839.3, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 4334.7, duration = 481.9，cost = 698.2
#     dropoff: req 6 at (0.0843372, 51.3798996), distance = 825.7, duration = 81.0
#     pickup: req 17 at (0.0794164, 51.3867846), distance = 1465.3, duration = 189.7
#     dropoff: req 17 at (0.0751755, 51.3735478), distance = 2043.7, duration = 211.2
# veh 3 at (0.0629431, 51.3708557) when t = 240.000; occupancy = 1/2;
#   service distance/time travelled: 622.4, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 3147.8, duration = 430.7，cost = 731.3
#     pickup: req 20 at (0.0558905, 51.3687900), distance = 686.6, duration = 90.6
#     dropoff: req 20 at (0.0642029, 51.3652591), distance = 1029.8, duration = 164.7
#     dropoff: req 13 at (0.0739150, 51.3585900), distance = 1431.4, duration = 175.4
# veh 4 at (0.0546164, 51.3775184) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.1060023, 51.4103794) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 1605.5, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7336.3, duration = 803.5，cost = 838.0
#     pickup: req 3 at (0.1058691, 51.4118283), distance = 465.2, duration = 69.1
#     dropoff: req 3 at (0.0950427, 51.3625064), distance = 6871.1, duration = 734.4
# veh 6 at (0.0594597, 51.3893874) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 764.4, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2703.8, duration = 291.9，cost = 385.2
#     pickup: req 12 at (0.0420004, 51.3946469), distance = 1818.2, duration = 186.6
#     dropoff: req 12 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
# veh 7 at (0.0739437, 51.3911994) when t = 240.000; occupancy = 1/2;
#   service distance/time travelled: 1215.1, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 8636.7, duration = 765.4，cost = 1595.9
#     pickup: req 15 at (0.1141772, 51.3978578), distance = 3861.0, duration = 366.0
#     dropoff: req 5 at (0.0918767, 51.4176560), distance = 3357.2, duration = 281.5
#     dropoff: req 15 at (0.1047756, 51.4245615), distance = 1418.5, duration = 117.9
# veh 8 at (0.0451768, 51.3943510) when t = 240.000; occupancy = 2/2;
#   service distance/time travelled: 1799.2, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 663.6, duration = 68.5，cost = 137.0
#     dropoff: req 1 at (0.0452234, 51.3999896), distance = 663.3, duration = 68.5
#     dropoff: req 10 at (0.0452234, 51.3999896), distance = 0.3, duration = 0.0
# veh 9 at (0.1074539, 51.3538950) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0890203, 51.3909604) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 1581.3, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2303.1, duration = 248.0，cost = 295.9
#     pickup: req 9 at (0.0933248, 51.3928668), distance = 680.5, duration = 95.8
#     dropoff: req 9 at (0.0894257, 51.4023735), distance = 1622.6, duration = 152.2
# veh 11 at (0.0892088, 51.3687431) when t = 240.000; occupancy = 1/2;
#   service distance/time travelled: 1347.8, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 2785.0, duration = 275.2，cost = 275.2
#     dropoff: req 8 at (0.1070611, 51.3758154), distance = 2785.0, duration = 275.2
# veh 12 at (0.0601069, 51.3697513) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 422.8, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2467.6, duration = 277.5，cost = 292.2
#     pickup: req 14 at (0.0628968, 51.3712046), distance = 274.7, duration = 29.5
#     dropoff: req 14 at (0.0739150, 51.3585900), distance = 2192.9, duration = 248.0
# veh 13 at (0.0567602, 51.3504013) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0921313, 51.3622265) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 122.5, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4315.5, duration = 499.6，cost = 617.0
#     pickup: req 18 at (0.0907837, 51.3795975), distance = 2209.6, duration = 234.8
#     dropoff: req 18 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 15 at (0.0649702, 51.3595653) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 106.6, 30.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6077.4, duration = 652.3，cost = 872.9
#     pickup: req 19 at (0.0794164, 51.3867846), distance = 4033.7, duration = 441.1
#     dropoff: req 19 at (0.0751755, 51.3735478), distance = 2043.7, duration = 211.2
# veh 16 at (0.0771489, 51.3770397) when t = 240.000; occupancy = 1/2;
#   service distance/time travelled: 1910.3, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 5009.2, duration = 477.9，cost = 477.9
#     dropoff: req 2 at (0.0603542, 51.4061583), distance = 5009.2, duration = 477.9
# veh 17 at (0.0539679, 51.4075091) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 1291.1, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8718.5, duration = 738.4，cost = 860.2
#     pickup: req 11 at (0.0919035, 51.4175855), distance = 2975.8, duration = 243.6
#     dropoff: req 11 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 18 at (0.1132434, 51.3859912) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 1654.2, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 3204.0, duration = 420.9，cost = 473.9
#     pickup: req 4 at (0.1176802, 51.3898180), distance = 741.9, duration = 105.9
#     dropoff: req 4 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 19 at (0.0725948, 51.3484262) when t = 240.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 20 vehicles of capacity 2; 360.0 trips/h
#   at t = 270.000, 27 requests, in which 7 in queue
# req 16 from (0.0919035, 51.4175855) to (0.0712996, 51.3933688) at t = 191.349
#   latest pickup at t = 671.349, latest dropoff at t = 1660.749
#   pickup at t = -1.000, dropoff at t = -1.000
# req 21 from (0.1229523, 51.3968114) to (0.1015619, 51.3777827) at t = 220.808
#   latest pickup at t = 700.808, latest dropoff at t = 1811.408
#   pickup at t = -1.000, dropoff at t = -1.000
# req 22 from (0.0919035, 51.4175855) to (0.0712996, 51.3933688) at t = 223.287
#   latest pickup at t = 703.287, latest dropoff at t = 1692.687
#   pickup at t = -1.000, dropoff at t = -1.000
# req 23 from (0.0933248, 51.3928668) to (0.0894257, 51.4023735) at t = 240.645
#   latest pickup at t = 720.645, latest dropoff at t = 1025.045
#   pickup at t = -1.000, dropoff at t = -1.000
# req 24 from (0.0558905, 51.3687900) to (0.0642029, 51.3652591) at t = 245.754
#   latest pickup at t = 725.754, latest dropoff at t = 1055.154
#   pickup at t = -1.000, dropoff at t = -1.000
# req 25 from (0.0907837, 51.3795975) to (0.0746622, 51.3897401) at t = 246.659
#   latest pickup at t = 726.659, latest dropoff at t = 1256.259
#   pickup at t = -1.000, dropoff at t = -1.000
# req 26 from (0.0919035, 51.4175855) to (0.0712996, 51.3933688) at t = 256.490
#   latest pickup at t = 736.490, latest dropoff at t = 1725.890
#   pickup at t = -1.000, dropoff at t = -1.000
# veh 0 at (0.0785412, 51.4133483) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 2776.9, 240.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 6813.0, duration = 595.5，cost = 645.9
#     pickup: req 0 at (0.0919035, 51.4175855), distance = 1070.3, duration = 100.7
#     dropoff: req 0 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 1 at (0.1095191, 51.3885060) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 2472.6, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4887.0, duration = 398.5，cost = 451.6
#     pickup: req 7 at (0.1141772, 51.3978578), distance = 1194.7, duration = 106.2
#     dropoff: req 7 at (0.1047756, 51.4245615), distance = 3692.3, duration = 292.3
# veh 2 at (0.0841703, 51.3811176) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 2138.2, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 4035.7, duration = 451.9，cost = 623.2
#     dropoff: req 6 at (0.0843372, 51.3798996), distance = 526.7, duration = 51.0
#     pickup: req 17 at (0.0794164, 51.3867846), distance = 1465.3, duration = 189.7
#     dropoff: req 17 at (0.0751755, 51.3735478), distance = 2043.7, duration = 211.2
# veh 3 at (0.0594846, 51.3695078) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 910.4, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 2859.8, duration = 400.7，cost = 656.3
#     pickup: req 20 at (0.0558905, 51.3687900), distance = 398.6, duration = 60.6
#     dropoff: req 20 at (0.0642029, 51.3652591), distance = 1029.8, duration = 164.7
#     dropoff: req 13 at (0.0739150, 51.3585900), distance = 1431.4, duration = 175.4
# veh 4 at (0.0546164, 51.3775184) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.1038398, 51.4112758) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 1812.4, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7129.4, duration = 773.5，cost = 793.0
#     pickup: req 3 at (0.1058691, 51.4118283), distance = 258.3, duration = 39.1
#     dropoff: req 3 at (0.0950427, 51.3625064), distance = 6871.1, duration = 734.4
# veh 6 at (0.0551665, 51.3905117) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 1082.9, 120.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2385.3, duration = 261.9，cost = 340.2
#     pickup: req 12 at (0.0420004, 51.3946469), distance = 1499.7, duration = 156.6
#     dropoff: req 12 at (0.0452234, 51.3999896), distance = 885.6, duration = 105.3
# veh 7 at (0.0768864, 51.3903709) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 1479.3, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 8372.5, duration = 735.4，cost = 1520.9
#     pickup: req 15 at (0.1141772, 51.3978578), distance = 3596.8, duration = 336.0
#     dropoff: req 5 at (0.0918767, 51.4176560), distance = 3357.2, duration = 281.5
#     dropoff: req 15 at (0.1047756, 51.4245615), distance = 1418.5, duration = 117.9
# veh 8 at (0.0460789, 51.3968397) when t = 270.000; occupancy = 2/2;
#   service distance/time travelled: 2102.5, 240.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 360.2, duration = 38.5，cost = 77.0
#     dropoff: req 1 at (0.0452234, 51.3999896), distance = 359.9, duration = 38.5
#     dropoff: req 10 at (0.0452234, 51.3999896), distance = 0.3, duration = 0.0
# veh 9 at (0.1074539, 51.3538950) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 10 at (0.0898108, 51.3925691) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 1867.5, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2016.9, duration = 218.0，cost = 250.9
#     pickup: req 9 at (0.0933248, 51.3928668), distance = 394.3, duration = 65.8
#     dropoff: req 9 at (0.0894257, 51.4023735), distance = 1622.6, duration = 152.2
# veh 11 at (0.0880155, 51.3706652) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 1630.2, 180.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 1 leg(s), distance = 2502.6, duration = 245.2，cost = 245.2
#     dropoff: req 8 at (0.1070611, 51.3758154), distance = 2502.6, duration = 245.2
# veh 12 at (0.0627117, 51.3711039) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 700.0, 90.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 3181.1, duration = 437.2，cost = 747.5
#     pickup: req 24 at (0.0558905, 51.3687900), distance = 719.9, duration = 97.1
#     dropoff: req 24 at (0.0642029, 51.3652591), distance = 1029.8, duration = 164.7
#     dropoff: req 14 at (0.0739150, 51.3585900), distance = 1431.4, duration = 175.4
# veh 13 at (0.0567602, 51.3504013) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 0 leg(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 14 at (0.0923503, 51.3639056) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 377.3, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 4060.7, duration = 469.6，cost = 572.0
#     pickup: req 18 at (0.0907837, 51.3795975), distance = 1954.8, duration = 204.8
#     dropoff: req 18 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8
# veh 15 at (0.0646003, 51.3612224) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 327.3, 60.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 5856.7, duration = 622.3，cost = 827.8
#     pickup: req 19 at (0.0794164, 51.3867846), distance = 3813.0, duration = 411.1
#     dropoff: req 19 at (0.0751755, 51.3735478), distance = 2043.7, duration = 211.2
# veh 16 at (0.0791383, 51.3796424) when t = 270.000; occupancy = 1/2;
#   service distance/time travelled: 2243.2, 240.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 3 leg(s), distance = 7020.4, duration = 695.1，cost = 1270.3
#     pickup: req 23 at (0.0933248, 51.3928668), distance = 2567.3, duration = 282.0
#     dropoff: req 23 at (0.0894257, 51.4023735), distance = 1622.6, duration = 152.2
#     dropoff: req 2 at (0.0603542, 51.4061583), distance = 2830.5, duration = 260.9
# veh 17 at (0.0598113, 51.4086008) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 1741.2, 150.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 8268.4, duration = 708.4，cost = 815.2
#     pickup: req 11 at (0.0919035, 51.4175855), distance = 2525.7, duration = 213.6
#     dropoff: req 11 at (0.0712996, 51.3933688), distance = 5742.7, duration = 494.8
# veh 18 at (0.1137440, 51.3878542) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 1865.4, 210.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 2992.8, duration = 390.9，cost = 428.9
#     pickup: req 4 at (0.1176802, 51.3898180), distance = 530.7, duration = 75.9
#     dropoff: req 4 at (0.1004065, 51.3757290), distance = 2462.1, duration = 315.0
# veh 19 at (0.0725948, 51.3484262) when t = 270.000; occupancy = 0/2;
#   service distance/time travelled: 0.0, 0.0; rebalancing distance/time travelled: 0.0, 0.0
#   has 2 leg(s), distance = 7021.9, duration = 709.9，cost = 932.5
#     pickup: req 25 at (0.0907837, 51.3795975), distance = 4916.0, duration = 445.1
#     dropoff: req 25 at (0.0746622, 51.3897401), distance = 2105.9, duration = 264.8

# %%
fig = plt.figure(figsize=(16,10))
model.draw()
mplleaflet.display(fig)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="600"></iframe>

# %%
for v in model.vehs:
    print(v)

# %%
osrm.kill_server()
