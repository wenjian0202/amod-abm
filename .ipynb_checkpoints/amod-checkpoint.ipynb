# %%
import time
import csv
import pandas as pd
import argparse
import numpy as np
import random
from multiprocessing import *
import mplleaflet
import matplotlib.pyplot as plt
from collections import deque

from lib.OsrmEngine import *
from lib.Agents import *
from lib.Demand import *

# %%
exe_loc = './osrm-backend-5.6.0/build/osrm-routed'
map_loc = './osrm-backend-5.6.0/greater-london-latest.osrm'

osrm = OsrmEngine(exe_loc, map_loc)
osrm.start_server()
osrm = OsrmEngine(exe_loc, map_loc)
osrm.start_server()
# Out:
# The routing server "http://0.0.0.0:5000" starts running
# The routing server "http://0.0.0.0:5000" is killed
# The routing server "http://0.0.0.0:5000" starts running

# %%
olat = 0.089653
olng = 51.373206
dlat = 0.089282
dlng = 51.350675

N = 1000
stime = time.time()
for i in range(N):
    o1 = random.uniform(-0.01, 0.01)
    o2 = random.uniform(-0.01, 0.01)
    d1 = random.uniform(-0.01, 0.01)
    d2 = random.uniform(-0.01, 0.01)
    out = osrm.get_routing(olat+o1, olng+o2, dlat+d1, dlng+d2)
etime = time.time()
print("Avarage running time per request: %.3fms" % ((etime-stime)*1000/N) )
# Out:
# Avarage running time per request: 4.804ms

# %%
import copy

B_W = 1.5
B_V = 1.0

class Leg(object):
    """ 
    Leg is a class for legs in the route
    Attributes:
        rid: request id (if rebalancing then -1)
        pod: pickup (+1) or dropoff (-1), rebalancing (0)
        tlat: target latitude
        tlng: target longitude
        d: total distance 
        t: total duration
        steps: a list of steps
    """
    def __init__(self, rid=-1, pod=0, d=0.0, t=0.0, steps=[]):
        self.rid = rid
        seld.pod = pod
        self.d = d
        self.t = t
        self.steps = deque([])
        
    def __str__(self):
        return "leg: distance = %.1f, duration = %.1f, number of steps = %d" % (self.d, self.t, len(self.steps) )

class Veh(object):
    """ 
    Veh is a class for vehicles
    Attributes:
        id: sequential unique id
        T: system time at current state
        lat: current latitude
        lng: current longitude
        tlat: target (end of route) latitude
        tlng: target (end of route) longitude
        K: capacity
        n: number of passengers on board
        route: a list of legs
        t: total duration of the route
        d: total distance of the route
        c: total cost (generalized time) of the passegners
        Ds: accumulated service distance traveled
        Ts: accumulated service time traveled
        Dr: accumulated rebalancing distance traveled
        Tr: accumulated rebalancing time traveled
    """ 
    def __init__(self, id, K=4, lat=0.089653, lng=51.373206, T=0.0):
        self.id = id
        self.T = T
        self.lat = lat
        self.lng = lng
        self.tlat = lat
        self.tlng = lng
        self.K = K
        self.n = 0
        self.route = deque([])
        self.t = 0.0
        self.d = 0.0
        self.c = 0.0
        self.Ds = 0.0
        self.Ts = 0.0
        self.Dr = 0.0
        self.Tr = 0.0
        
    def get_location(self):
        return (self.lat, self.lng)
    
    def get_target_location(self):
        return (self.tlat, self.tlng)
    
    def jump_to_location(self, lat, lng):
        self.lat = lat
        self.lng = lng
        
    def build_route(self, osrm, route):
        self.clear_route()
        for (rid, pod, tlat, tlng) in route:
            self.add_leg(osrm, rid, pod, tlat, tlng)
        self.update_cost()
        
    def clear_route(self):
        self.route.clear()
        self.d = 0.0
        self.t = 0.0
        self.c = 0.0
        self.tlat = self.lat
        self.tlng = self.lng
    
    def add_leg(self, osrm, rid, pod, tlat, tlng):
        out = osrm.get_routing(self.tlat, self.tlng, tlat, tlng)
        assert len(out['legs']) == 1
        leg = Leg(rid, pod, tlat, tlng, 
                  out['legs'][0]['distance'], out['legs'][0]['duration'], steps=[])
        for s in out['legs'][0]['steps']:
            step = Step(s['distance'], s['duration'], s['geometry']['coordinates'])
            leg.steps.append(step)
        assert len(step.geo) == 2
        assert step.geo[0] == step.geo[1]
        self.route.append(leg)
        self.tlat = leg.steps[-1].geo[1][0]
        self.tlng = leg.steps[-1].geo[1][1]
        self.d += leg.d
        self.t += leg.t
        assert len(self.jobs) == len(self.route)
        
    def update_cost(self):
        c = 0.0
        t = 0.0
        n = self.n
        for leg in self.route:
            t += leg.t
            c += n * leg.t * B_V
            n += leg.pod
            c += t * B_W if leg.pod == 1 else 0
        self.c = c
        
    def move_to_time(self, T):
        dT = T - self.T
        if dT <= 0:
            return []
        done = []
        while dT > 0 and len(self.route) > 0:
            leg = self.route[0]
            if leg.t < dT:
                dT -= leg.t
                self.T += leg.t
                self.Ts += leg.t if leg.rid != -1 else 0
                self.Ds += leg.d if leg.rid != -1 else 0
                self.Tr += leg.t if leg.rid == -1 else 0
                self.Dr += leg.d if leg.rid == -1 else 0
                self.jump_to_location(leg.tlat, leg.tlng)
                self.n += leg.pod
                done.append( (leg.rid, leg.pod, self.T) )
                self.pop_leg()
            else:
                while dT > 0 and len(self.route[0].steps) > 0:
                    step = self.route[0].steps[0]
                    if step.t < dT:
                        dT -= step.t
                        self.Ts += step.t if leg.rid != -1 else 0
                        self.Ds += step.d if leg.rid != -1 else 0
                        self.Tr += step.t if leg.rid == -1 else 0
                        self.Dr += step.d if leg.rid == -1 else 0
                        self.pop_step()
                    else:
                        pct = dT / step.t
                        self.Ts += dT if leg.rid != -1 else 0
                        self.Ds += step.d * pct if leg.rid != -1 else 0
                        self.Tr += dT if leg.rid == -1 else 0
                        self.Dr += step.d * pct if leg.rid == -1 else 0
                        self.cut_step(pct)
                        self.jump_to_location(step.geo[0][0], step.geo[0][1])
                        self.T = T
                        return done
        assert dT > 0
        assert len(self.route) == 0 and self.n == 0
        assert np.isclose(self.d, 0.0)
        assert np.isclose(self.t, 0.0)
        self.T = T
        self.d = 0.0
        self.t = 0.0
        return done
        
    def pop_leg(self):
        leg = self.route.popleft()
        self.d -= leg.d
        self.t -= leg.t
        
    def pop_step(self):
        step = self.route[0].steps.popleft()
        self.t -= step.t
        self.d -= step.d
        self.route[0].t -= step.t
        self.route[0].d -= step.d
        
    def cut_step(self, pct):
        step = self.route[0].steps[0]
        dis = 0
        sega = step.geo[0]
        for segb in step.geo[1:]:
            dis += np.sqrt( (sega[0] - segb[0])**2 + (sega[1] - segb[1])**2)
            sega = segb
        dis_ = 0
        sega = step.geo[0]
        for segb in step.geo[1:]:
            _dis = np.sqrt( (sega[0] - segb[0])**2 + (sega[1] - segb[1])**2)
            dis_ += _dis
            if dis_ / dis > pct:
                break
            sega = segb
        while step.geo[0] != sega:
            step.geo.pop(0)
        _pct = (pct * dis - dis_ + _dis) / _dis
        
        step.geo[0][0] = sega[0] + _pct * (segb[0] - sega[0])
        step.geo[0][1] = sega[1] + _pct * (segb[1] - sega[1])
        
        self.t -= step.t * pct
        self.d -= step.d * pct
        self.route[0].t -= step.t * pct
        self.route[0].d -= step.d * pct
        self.route[0].steps[0].t -= step.t * pct
        self.route[0].steps[0].d -= step.d * pct  
    
    def get_cost_of_route(self, osrm, route):
        c = 0.0
        t = 0.0
        n = self.n
        lat = self.lat
        lng = self.lng
        for (rid, pod, tlat, tlng) in route:
            dt = osrm.get_duration(lat, lng, tlat, tlng)
            t += dt
            c += n * dt * B_V
            n += pod
            c += t * B_W if pod == 1 else 0
            lat = tlat
            lng = tlng
        return c 
    
    def draw(self):
        plt.plot(self.lat, self.lng, 'b', marker='o')
        for leg in self.route:
            for step in leg.steps:
                geo = np.transpose( step.geo )
                if l == 0:
                    plt.plot(geo[0], geo[1], 'b', linestyle='-')
                else:
                    plt.plot(geo[0], geo[1], 'b', linestyle='--', dashes=(1, 3))
                        
    def __str__(self):
        str =  "veh %d at (%.7f, %.7f) when t = %.3f; occupancy = %d/%d;" % (
            self.id, self.lat, self.lng, self.T, self.n, self.K)
        str += "\n  service distance/time travelled: %.1f, %.1f; rebalancing distance/time travelled: %.1f, %.1f" % (
            self.Ds, self.Ts, self.Dr, self.Tr)
        str += "\n  has %d leg(s), distance = %.1f, duration = %.1f，cost = %.1f" % (
            len(self.route), self.d, self.t, self.c)
        for leg in self.route:
            str += "\n    %s: req %d at (%.7f, %.7f), distance = %.1f, duration = %.1f" % (
                "pickup" if leg.pod == 1 else "dropoff" if leg.pod == -1 else "rebalancing",
                leg.rid, leg.tlat, leg.tlng, leg.d, leg.t)
        return str
    

class Req(object):
    """ 
    Req is a class for requests
    Attributes:
        id: sequential unique id
        Tr: request time
        olat: origin latitude
        olng: origin longitude
        dlat: destination latitude
        dlng: destination longitude
    """
    def __init__(self, id, Tr, olat=0.115662, olng=51.374282, dlat=0.089282, dlng=51.350675):
        self.id = id
        self.Tr = Tr
        self.olat = olat
        self.olng = olng
        self.dlat = dlat
        self.dlng = dlng
    
    def get_origin(self):
        return (self.olat, self.olng)
    
    def get_destination(self):
        return (self.dlat, self.dlng)
    
    def draw(self):
        plt.plot(self.olat, self.olng, 'r', marker='s')
        plt.plot(self.dlat, self.dlng, 'r', marker='*')
        plt.plot([self.olat, self.dlat], [self.olng, self.dlng], 'r', linestyle='--', dashes=(0.5,1.5))
    
    def __str__(self):
        return "req %d from (%.7f, %.7f) to (%.7f, %.7f) at t = %.3f" % (
            self.id, self.olat, self.olng, self.dlat, self.dlng, self.Tr)
    

class Model(object):
    """
    Model is the class for the AMoD system
    Attributes:
        T: system time at current state
        D: average arrival interval (sec)
        demand: demand matrix
        V: number of vehicles
        K: capacity of vehicles
        vehs: the list of vehicles
        N: number of requests
        reqs: the list of requests
        queue: requests in the queue
    """ 
    def __init__(self, D, demand, V=2, K=4):
        self.T = 0.0
        self.D = D
        self.demand = demand
        self.V = V
        self.K = K
        self.vehs = []
        for i in range(V):
            self.vehs.append(Veh(i, K=K))
        self.N = 0
        self.reqs = []
        self.queue = deque([])
        
    def generate_request(self):
        dt = self.D * np.random.exponential()
        rand = np.random.rand()
        for d in demand:
            if d[4] > rand:
                req = Req(0 if self.N == 0 else self.reqs[-1].id+1,
                          dt if self.N == 0 else self.reqs[-1].Tr+dt,
                          d[1], d[0], d[3], d[2])
                break
        self.N += 1
        return req
        
    def generate_requests_to_time(self, T):
        if self.N == 0:
            req = self.generate_request()
            self.reqs.append(req)
        while self.reqs[-1].Tr <= T:
            req = self.generate_request()
            self.queue.append(self.reqs[-1])
            self.reqs.append(req)
        assert self.N == len(self.reqs)
        
    def dispatch_at_time(self, osrm, T):
        self.T = T
        for v in self.vehs:
            v.move_to_time(T)
        self.generate_requests_to_time(T)
        print(self)
        self.assign(osrm)
        for v in self.vehs:
            print(v)
        
    def assign(self, osrm):
        l = len(self.queue)
        for i in range(l):
            req = self.queue.popleft()
            if not self.insert_heuristics(osrm, req):
                self.queue.append(req)
        
    def insert_heuristics(self, osrm, req):
        dc = np.inf
        v_ = None
        r_ = None
        for v in self.vehs:
            route = []
            for leg in v.route:
                route.append(leg.rid, leg.pod, leg.tlat, leg.tlng)
            l = len(route)
            c = v.c
            for i in range(l+1):
                for j in range(i+1, l+2):
                    route.insert(i, (req.id, 1, req.olat, req.olng) )
                    route.insert(j, (req.id, -1, req.dlat, req.dlng) )
                    c_ = v.get_cost_of_route(osrm, route)
                    if c_ - c < dc:
                        dc = c_ - c
                        v_ = v
                        r_ = copy.deepcopy(route)
                    route.pop(j)
                    route.pop(i)
        if v_ != None:
            v_.build_route(r_)
            return True
        else:
            return False
    
    def draw(self):
        for v in self.vehs:
            v.draw()
        for r in self.reqs[:-1]:
            r.draw()
        
    def __str__(self):
        str = "AMoD system: %d vehicles of capacity %d; %.1f trips/h" % (self.V, self.K, 3600/self.D)
        str += "\n  at t = %.3f, %d requests, in which %d in queue" % ( self.T, self.N-1, len(self.queue) )
        for r in self.queue:
            str += "\n    " + r.__str__()
        return str

# %%
model = Model(60, demand, V=1, K=4)
T = 0

# %%
model.dispatch_at_time(osrm, T)
T += 50

fig = plt.figure(figsize=(16,10))
model.draw()
mplleaflet.display(fig)
# Out:
# AMoD system: 1 vehicles of capacity 4; 60.0 trips/h
#   at t = 50.000, 1 requests, in which 1 in queue
#     req 0 from (0.1015402, 51.3547400) to (0.1009038, 51.3774429) at t = 24.860
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-569beb7ae7a7> in <module>()
# ----> 1 model.dispatch_at_time(osrm, T)
#       2 T += 50
#       3
#       4 fig = plt.figure(figsize=(16,10))
#       5 model.draw()
#
# <ipython-input-99-9adfb11476cb> in dispatch_at_time(self, osrm, T)
#     335         self.generate_requests_to_time(T)
#     336         print(self)
# --> 337         self.assign(osrm)
#     338         for v in self.vehs:
#     339             print(v)
#
# <ipython-input-99-9adfb11476cb> in assign(self, osrm)
#     343         for i in range(l):
#     344             req = self.queue.popleft()
# --> 345             if not self.insert_heuristics(osrm, req):
#     346                 self.queue.append(req)
#     347
#
# <ipython-input-99-9adfb11476cb> in insert_heuristics(self, osrm, req)
#     368                     route.pop(i)
#     369         if v_ != None:
# --> 370             v_.build_route(r_)
#     371             return True
#     372         else:
#
# TypeError: build_route() missing 1 required positional argument: 'route'

# %%
stime = time.time()
for T in range(0,300,30):
    model.dispatch_at_time(osrm, T)
etime = time.time()
runtime = etime - stime
# Out:
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 0.000, 0 requests, in which 0 in queue
# veh 0 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 1 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 0.000, 1 requests, in which 1 in queue
#     req 0 from (0.0713160, 51.3724747) to (0.0843372, 51.3798996) at t = 23.336
# veh 0 at (0.0896530, 51.3732060) when t = 402.500; occupancy = 0/4
#   has 2 job(s), distance = 3870.8, duration = 402.5，cost = 494.2
#     pickup: req 0 at (0.0713160, 51.3724747)
#     dropoff: req 0 at (0.0843372, 51.3798996)
# veh 1 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 30.000, 1 requests, in which 0 in queue
# veh 0 at (0.0902004, 51.3723306) when t = 372.500; occupancy = 0/4
#   has 2 job(s), distance = 3765.9, duration = 372.5，cost = 494.2
#     pickup: req 0 at (0.0713160, 51.3724747)
#     dropoff: req 0 at (0.0843372, 51.3798996)
# veh 1 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 2 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 60.000, 2 requests, in which 1 in queue
#     req 1 from (0.0794164, 51.3867846) to (0.0751755, 51.3735478) at t = 81.518
# veh 0 at (0.0873346, 51.3727809) when t = 342.500; occupancy = 0/4
#   has 2 job(s), distance = 3515.2, duration = 342.5，cost = 494.2
#     pickup: req 0 at (0.0713160, 51.3724747)
#     dropoff: req 0 at (0.0843372, 51.3798996)
# veh 1 at (0.0896530, 51.3732060) when t = 533.500; occupancy = 0/4
#   has 2 job(s), distance = 4570.3, duration = 533.5，cost = 694.7
#     pickup: req 1 at (0.0794164, 51.3867846)
#     dropoff: req 1 at (0.0751755, 51.3735478)
# veh 2 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 3 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 4 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 5 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 90.000, 6 requests, in which 4 in queue
#     req 2 from (0.0713160, 51.3724747) to (0.0843372, 51.3798996) at t = 97.541
#     req 3 from (0.0628968, 51.3712046) to (0.0739150, 51.3585900) at t = 112.155
#     req 4 from (0.0933248, 51.3928668) to (0.0894257, 51.4023735) at t = 112.389
#     req 5 from (0.1141772, 51.3978578) to (0.1047756, 51.4245615) at t = 116.984
# veh 0 at (0.0829708, 51.3727306) when t = 314.100; occupancy = 0/4
#   has 4 job(s), distance = 3200.1, duration = 314.1，cost = 723.0
#     pickup: req 2 at (0.0713160, 51.3724747)
#     pickup: req 0 at (0.0713160, 51.3724747)
#     dropoff: req 2 at (0.0843372, 51.3798996)
#     dropoff: req 0 at (0.0843372, 51.3798996)
# veh 1 at (0.0903020, 51.3721927) when t = 503.500; occupancy = 0/4
#   has 2 job(s), distance = 4448.3, duration = 503.5，cost = 694.7
#     pickup: req 1 at (0.0794164, 51.3867846)
#     dropoff: req 1 at (0.0751755, 51.3735478)
# veh 2 at (0.0896530, 51.3732060) when t = 481.900; occupancy = 0/4
#   has 2 job(s), distance = 4384.7, duration = 481.9，cost = 598.9
#     pickup: req 3 at (0.0628968, 51.3712046)
#     dropoff: req 3 at (0.0739150, 51.3585900)
# veh 3 at (0.0896530, 51.3732060) when t = 531.200; occupancy = 0/4
#   has 2 job(s), distance = 4942.7, duration = 531.2，cost = 720.7
#     pickup: req 4 at (0.0933248, 51.3928668)
#     dropoff: req 4 at (0.0894257, 51.4023735)
# veh 4 at (0.0896530, 51.3732060) when t = 710.600; occupancy = 0/4
#   has 2 job(s), distance = 8337.9, duration = 710.6，cost = 919.8
#     pickup: req 5 at (0.1141772, 51.3978578)
#     dropoff: req 5 at (0.1047756, 51.4245615)
# veh 5 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 120.000, 7 requests, in which 1 in queue
#     req 6 from (0.0713160, 51.3724747) to (0.0843372, 51.3798996) at t = 140.096
# veh 0 at (0.0786916, 51.3731901) when t = 285.900; occupancy = 0/4
#   has 6 job(s), distance = 2898.4, duration = 285.9，cost = 957.6
#     pickup: req 6 at (0.0713160, 51.3724747)
#     pickup: req 2 at (0.0713160, 51.3724747)
#     pickup: req 0 at (0.0713160, 51.3724747)
#     dropoff: req 6 at (0.0843372, 51.3798996)
#     dropoff: req 2 at (0.0843372, 51.3798996)
#     dropoff: req 0 at (0.0843372, 51.3798996)
# veh 1 at (0.0918619, 51.3723820) when t = 473.500; occupancy = 0/4
#   has 2 job(s), distance = 4224.2, duration = 473.5，cost = 694.7
#     pickup: req 1 at (0.0794164, 51.3867846)
#     dropoff: req 1 at (0.0751755, 51.3735478)
# veh 2 at (0.0902004, 51.3723306) when t = 451.900; occupancy = 0/4
#   has 2 job(s), distance = 4279.8, duration = 451.9，cost = 598.9
#     pickup: req 3 at (0.0628968, 51.3712046)
#     dropoff: req 3 at (0.0739150, 51.3585900)
# veh 3 at (0.0903020, 51.3721927) when t = 501.200; occupancy = 0/4
#   has 2 job(s), distance = 4820.7, duration = 501.2，cost = 720.7
#     pickup: req 4 at (0.0933248, 51.3928668)
#     dropoff: req 4 at (0.0894257, 51.4023735)
# veh 4 at (0.0903020, 51.3721927) when t = 680.600; occupancy = 0/4
#   has 2 job(s), distance = 8215.9, duration = 680.6，cost = 919.8
#     pickup: req 5 at (0.1141772, 51.3978578)
#     dropoff: req 5 at (0.1047756, 51.4245615)
# veh 5 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 150.000, 8 requests, in which 1 in queue
#     req 7 from (0.1015402, 51.3547400) to (0.1009038, 51.3774429) at t = 160.033
# veh 0 at (0.0745225, 51.3733375) when t = 255.900; occupancy = 0/4
#   has 6 job(s), distance = 2608.2, duration = 255.9，cost = 957.6
#     pickup: req 6 at (0.0713160, 51.3724747)
#     pickup: req 2 at (0.0713160, 51.3724747)
#     pickup: req 0 at (0.0713160, 51.3724747)
#     dropoff: req 6 at (0.0843372, 51.3798996)
#     dropoff: req 2 at (0.0843372, 51.3798996)
#     dropoff: req 0 at (0.0843372, 51.3798996)
# veh 1 at (0.0899430, 51.3749180) when t = 443.500; occupancy = 0/4
#   has 2 job(s), distance = 3912.1, duration = 443.5，cost = 694.7
#     pickup: req 1 at (0.0794164, 51.3867846)
#     dropoff: req 1 at (0.0751755, 51.3735478)
# veh 2 at (0.0873032, 51.3727806) when t = 421.900; occupancy = 0/4
#   has 2 job(s), distance = 4021.8, duration = 421.9，cost = 598.9
#     pickup: req 3 at (0.0628968, 51.3712046)
#     dropoff: req 3 at (0.0739150, 51.3585900)
# veh 3 at (0.0918619, 51.3723820) when t = 471.200; occupancy = 0/4
#   has 2 job(s), distance = 4596.6, duration = 471.2，cost = 720.7
#     pickup: req 4 at (0.0933248, 51.3928668)
#     dropoff: req 4 at (0.0894257, 51.4023735)
# veh 4 at (0.0940385, 51.3725680) when t = 650.600; occupancy = 0/4
#   has 2 job(s), distance = 7915.4, duration = 650.6，cost = 919.8
#     pickup: req 5 at (0.1141772, 51.3978578)
#     dropoff: req 5 at (0.1047756, 51.4245615)
# veh 5 at (0.0896530, 51.3732060) when t = 760.700; occupancy = 0/4
#   has 2 job(s), distance = 6860.8, duration = 760.7，cost = 939.4
#     pickup: req 7 at (0.1015402, 51.3547400)
#     dropoff: req 7 at (0.1009038, 51.3774429)
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 180.000, 8 requests, in which 0 in queue
# veh 0 at (0.0709240, 51.3730364) when t = 225.900; occupancy = 0/4
#   has 6 job(s), distance = 2313.2, duration = 225.9，cost = 957.6
#     pickup: req 6 at (0.0713160, 51.3724747)
#     pickup: req 2 at (0.0713160, 51.3724747)
#     pickup: req 0 at (0.0713160, 51.3724747)
#     dropoff: req 6 at (0.0843372, 51.3798996)
#     dropoff: req 2 at (0.0843372, 51.3798996)
#     dropoff: req 0 at (0.0843372, 51.3798996)
# veh 1 at (0.0902040, 51.3763457) when t = 413.500; occupancy = 0/4
#   has 2 job(s), distance = 3669.1, duration = 413.5，cost = 694.7
#     pickup: req 1 at (0.0794164, 51.3867846)
#     dropoff: req 1 at (0.0751755, 51.3735478)
# veh 2 at (0.0828958, 51.3727369) when t = 391.900; occupancy = 0/4
#   has 2 job(s), distance = 3703.3, duration = 391.9，cost = 598.9
#     pickup: req 3 at (0.0628968, 51.3712046)
#     dropoff: req 3 at (0.0739150, 51.3585900)
# veh 3 at (0.0899430, 51.3749180) when t = 441.200; occupancy = 0/4
#   has 2 job(s), distance = 4284.5, duration = 441.2，cost = 720.7
#     pickup: req 4 at (0.0933248, 51.3928668)
#     dropoff: req 4 at (0.0894257, 51.4023735)
# veh 4 at (0.0981997, 51.3731932) when t = 620.600; occupancy = 0/4
#   has 2 job(s), distance = 7597.8, duration = 620.6，cost = 919.8
#     pickup: req 5 at (0.1141772, 51.3978578)
#     dropoff: req 5 at (0.1047756, 51.4245615)
# veh 5 at (0.0903020, 51.3721927) when t = 730.700; occupancy = 0/4
#   has 2 job(s), distance = 6738.8, duration = 730.7，cost = 939.4
#     pickup: req 7 at (0.1015402, 51.3547400)
#     dropoff: req 7 at (0.1009038, 51.3774429)
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 210.000, 8 requests, in which 0 in queue
# veh 0 at (0.0722374, 51.3734043) when t = 195.900; occupancy = 3/4
#   has 3 job(s), distance = 2036.2, duration = 195.9，cost = 957.6
#     dropoff: req 6 at (0.0843372, 51.3798996)
#     dropoff: req 2 at (0.0843372, 51.3798996)
#     dropoff: req 0 at (0.0843372, 51.3798996)
# veh 1 at (0.0880936, 51.3784154) when t = 383.500; occupancy = 0/4
#   has 2 job(s), distance = 3353.3, duration = 383.5，cost = 694.7
#     pickup: req 1 at (0.0794164, 51.3867846)
#     dropoff: req 1 at (0.0751755, 51.3735478)
# veh 2 at (0.0784947, 51.3732026) when t = 361.900; occupancy = 0/4
#   has 2 job(s), distance = 3384.7, duration = 361.9，cost = 598.9
#     pickup: req 3 at (0.0628968, 51.3712046)
#     dropoff: req 3 at (0.0739150, 51.3585900)
# veh 3 at (0.0904917, 51.3775638) when t = 411.200; occupancy = 0/4
#   has 2 job(s), distance = 3972.2, duration = 411.2，cost = 720.7
#     pickup: req 4 at (0.0933248, 51.3928668)
#     dropoff: req 4 at (0.0894257, 51.4023735)
# veh 4 at (0.1024119, 51.3727046) when t = 590.600; occupancy = 0/4
#   has 2 job(s), distance = 7294.0, duration = 590.6，cost = 919.8
#     pickup: req 5 at (0.1141772, 51.3978578)
#     dropoff: req 5 at (0.1047756, 51.4245615)
# veh 5 at (0.0932561, 51.3706366) when t = 700.700; occupancy = 0/4
#   has 2 job(s), distance = 6442.0, duration = 700.7，cost = 939.4
#     pickup: req 7 at (0.1015402, 51.3547400)
#     dropoff: req 7 at (0.1009038, 51.3774429)
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# AMoD system: 8 vehicles of capacity 4; 120.0 trips/h
#   at t = 240.000, 9 requests, in which 1 in queue
#     req 8 from (0.0687732, 51.3715380) to (0.0603542, 51.4061583) at t = 252.410
# veh 0 at (0.0761120, 51.3733120) when t = 1056.600; occupancy = 3/4
#   has 5 job(s), distance = 10599.7, duration = 1056.6，cost = 1794.6
#     dropoff: req 6 at (0.0843372, 51.3798996)
#     dropoff: req 2 at (0.0843372, 51.3798996)
#     dropoff: req 0 at (0.0843372, 51.3798996)
#     pickup: req 8 at (0.0687732, 51.3715380)
#     dropoff: req 8 at (0.0603542, 51.4061583)
# veh 1 at (0.0879377, 51.3812741) when t = 353.500; occupancy = 0/4
#   has 2 job(s), distance = 3048.6, duration = 353.5，cost = 694.7
#     pickup: req 1 at (0.0794164, 51.3867846)
#     dropoff: req 1 at (0.0751755, 51.3735478)
# veh 2 at (0.0740724, 51.3733506) when t = 331.900; occupancy = 0/4
#   has 2 job(s), distance = 3066.2, duration = 331.9，cost = 598.9
#     pickup: req 3 at (0.0628968, 51.3712046)
#     dropoff: req 3 at (0.0739150, 51.3585900)
# veh 3 at (0.0914176, 51.3802546) when t = 381.200; occupancy = 0/4
#   has 2 job(s), distance = 3659.2, duration = 381.2，cost = 720.7
#     pickup: req 4 at (0.0933248, 51.3928668)
#     dropoff: req 4 at (0.0894257, 51.4023735)
# veh 4 at (0.1065863, 51.3719066) when t = 560.600; occupancy = 0/4
#   has 2 job(s), distance = 6990.2, duration = 560.6，cost = 919.8
#     pickup: req 5 at (0.1141772, 51.3978578)
#     dropoff: req 5 at (0.1047756, 51.4245615)
# veh 5 at (0.0953204, 51.3680129) when t = 670.700; occupancy = 0/4
#   has 2 job(s), distance = 6124.2, duration = 670.7，cost = 939.4
#     pickup: req 7 at (0.1015402, 51.3547400)
#     dropoff: req 7 at (0.1009038, 51.3774429)
# veh 6 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0
# veh 7 at (0.0896530, 51.3732060) when t = 0.000; occupancy = 0/4
#   has 0 job(s), distance = 0.0, duration = 0.0，cost = 0.0

# %%
fig = plt.figure(figsize=(16,10))
model.draw()
mplleaflet.display(fig)

# %%
for v in model.vehs:
    print(v)

# %%
osrm.kill_server()
