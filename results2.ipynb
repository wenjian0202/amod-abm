# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

FS = [
    [80,90,100,110,120,130],
    [110,120,130,140,150,160],
    [90,100,110,120,130,140],
    [200,220,240,260,280,300]
]

DT = [
    [26959.0,24595.1,21844.7],
    [23420.1+5803.8, 19405.7+8960.7],
    [23222.1+6802.1],
    [7087.0,5201.4]
]

WT = [
    [217.2,192.5,171.8,155.7,136.0,128.2],
    [211.0,183.6,166.6,156.5,147.3,137.6],
    [222.3,192.3,175.6,160.2,145.1,137.1],
    [191.5,184.3,176.8,170.2,166.5,161.7]
]

# %%
plt.figure(figsize=(6,4))
handles = []
for i in [0,1,2,3]:
    handle = plt.plot(FS[i], WT[i],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.5)[0]
    handles.append(handle)
plt.legend(handles, ("ORP", "SAR", "DQN", "No Rebl"), scatterpoints=1)
plt.ylabel('Average Wait Time (s)')
plt.xlabel('Fleet Size')
plt.xlim((50,350))
plt.ylim((100,250))
plt.plot([50,350], [180,180], c='black', linestyle=":")
plt.show()
plt.savefig('fig3.eps', format='eps', dpi=1000, bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt


WT1 = np.array( [145.7189481,144.6495881,144.8347534,145.5202008,146.1525636,
                 145.0611548,151.7560214,141.3498185,145.9434034,142.3168543,
                 139.5559765,140.6044874,147.3072224,139.6331411,144.7108964,
                 143.2654968,148.6460406,146.0312908,148.1322536,140.3618787,
                 150.9115027,142.8215723,138.182621,138.9746639,147.5194394,
                 155.1599444,138.8374069,147.9431106,145.3018563,146.9893226,
                 158.0479646,142.2297315,131.4757472,153.2529749,159.3690188,
                 143.7985192,137.6966436,154.0861919,149.2494995,161.675581,
                 142.3874524,150.4799828,137.17003,146.6419888,155.1814783,
                 144.9125256,145.9846176,141.9274736,167.9982282,144.0529511] )
WT2 = np.array( [160.9780007,147.9855091,143.9088802,149.6183568,149.6205083,
                 151.3061636,165.5812507,166.223431,159.0579281,158.1848479,
                 135.9433529,164.6844536,152.2204642,151.2748752,169.0407388,
                 144.2912374,146.0363025,168.217404,150.1104447,164.1444717,
                 153.2624761,152.9098329,149.3101958,148.440691,153.2360698,
                 151.7435218,155.9144278,148.6227641,147.4103245,158.0712332,
                 152.527838,157.7862205,162.6728495,161.3849949,164.1517282,
                 153.7742141,173.5585259,160.7882509,162.4284321,151.1155976,
                 161.0593838,149.1649315,161.1161394,138.0852084,156.0134114,
                 160.2567948,170.3750808,150.7205922,159.5041169,158.1880221] )
WT3 = np.array( [150.9030832,144.7249394,149.2022656,155.1671359,145.7899266,
                 137.9979356,144.4663912,161.6002506,149.2526842,147.9566917,
                 141.5004861,153.9608746,155.3745817,157.8562349,150.9760092,
                 155.539352,141.5745932,153.6289378,153.513714,152.8108817,
                 148.6075843,158.988228,147.9378103,139.2198628,157.3339008,
                 153.7104791,147.1884712,152.0910952,153.7027773,145.7678214,
                 147.0798826,141.9226471,146.1291819,147.5052066,155.3623525,
                 145.0436714,151.9088604,149.6128959,148.9413417,152.9867849,
                 141.7875102,160.0533135,146.775011,161.5189362,144.5547793,
                 157.4514485,156.4362283,148.9405054,148.7015392,144.8759978] )
WT4 = np.array( [174.2950645,163.678199,178.239898,176.3893193,173.4265235,
                 172.9450483,179.1391491,170.4691177,169.6792241,168.0578072,
                 162.5900376,175.6582541,175.0229047,179.7649198,165.3286033,
                 155.4718004,167.4074295,182.5811157,161.8836047,169.0722318,
                 162.2178035,159.997924,169.2822672,166.0030388,171.1538386,
                 165.3833975,189.5422606,165.4400656,169.858232,181.5539057,
                 175.6595726,164.7580229,176.773284,162.9062191,163.5624742,
                 171.305343,176.2761436,163.0545559,167.7048291,180.5380495,
                 165.2335673,158.0985511,166.9833203,178.3282888,177.8607899,
                 176.6936365,178.8457166,170.7466146,162.7523564,172.7176636] )

SDT = np.array( [ 41545.39941, 41288.09486, 41437.85905, 41216.03277] )
RDT = np.array( [12548.65329, 16404.41606, 13136.11685, 0] )
SDT = SDT / 3000
RDT = RDT / 3000 + SDT

fig, ax1 = plt.subplots(figsize=(6,6))
ax1.boxplot([WT1, WT2, WT3, WT4], labels=["ORP", "SAR", "DQN", "No Rebl"], showfliers=False)
ax1.set_xlim((0,4))
ax1.set_ylim((0,220))
ax1.set_ylabel('Average Wait Time (s)')
ax2 = ax1.twinx()
d1 = ax2.bar([1,2,3,4], RDT, width=0.4)
d2 = ax2.bar([1,2,3,4], SDT, width=0.4)
ax2.legend([d1, d2], ["rebalancing distance", "service distance"])
ax2.set_ylim((0,50))
ax2.set_ylabel('Vehicle Distance Traveled (km/h)')
plt.show()
plt.savefig('fig2.eps', format='eps', dpi=1000, bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
lines = [line.rstrip('\n').split() for line in open('dqn_log.txt')]
rewards = []
for l in lines:
    if l[5] == 'reward:':
        rewards.append(float(l[6]))
rewards

fig, ax1 = plt.subplots()
ax1.plot(range(len(rewards)), rewards)
ax1.set_ylabel('Average Reward per Episode')
ax1.set_xlabel('Training Episode')
plt.show()
plt.savefig('fig1-2.eps', format='eps', dpi=1000, bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
