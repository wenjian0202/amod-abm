# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

NT = [
    [380,380,380],
    [571,571,571],
    [826,826,826],
    [1145,1145,1145]
]

FS = [
    [40,60,80],
    [60,80,100],
    [80,100,120],
    [100,120,140]
]

SR = [
    [92.2,96.8,99.0],
    [93.0,95.6,96.8],
    [93.1,97.1,97.9],
    [93.9,94.7,96.8]
]

VDT = [
    [29714.4,22606.7,18067.9],
    [27285.5,23282.7,19183.5],
    [26438.4,23345.3,21005.6],
    [26959.0,24595.1,21844.7]
]

WT = [
    [239.8,173.2,136.2],
    [199.4,162.4,131.1],
    [183.1,161.3,135.5],
    [177.8,155.7,136.0]
]

VT = [
    [478.5,447.1,471.1],
    [469.8,443.0,442.5],
    [458.8,460.7,455.2],
    [456.2,452.8,464.7]
]

TT = np.zeros((4,3))
for i in range(4):
    for j in range(3):
        TT[i][j] = 1.5*WT[i][j] + VT[i][j]
VMT = np.zeros((4,3)) 
TVDT = np.zeros((4,3))     
for i in range(4):
    for j in range(3):
        VDT[i][j] = VDT[i][j] / 1000
        TVDT[i][j] = VDT[i][j] * FS[i][j]
        VMT[i][j] = VDT[i][j]*VDT[i][j]/10

Colors = [
    [0,0,0],
    [1,1,1],
    [2,2,2],
    [3,3,3]
]

# %%
plt.figure()
handles = []
for i in [3,2,1,0]:
    handle = plt.scatter(FS[i], TT[i], s=VMT[i],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.5)
    handles.append(handle)
plt.legend(handles, ("ASC-3.5", "ASC-4.0", "ASC-4.5", "ASC-5.0"), scatterpoints=1)
plt.ylabel('Generalized Travel Time (s)')
plt.xlabel('Fleet Size')
plt.ylim((600,900))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
handles = []
for i in [3,2,1,0]:
    handle = plt.scatter(FS[i], TT[i], s=VMT[i],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.1)
    handles.append(handle)
for i in [3,2,1,0]:
    handle = plt.scatter(FS[i][1], TT[i][1], s=VMT[i][1],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.5)
plt.legend(handles, ("ASC-3.5", "ASC-4.0", "ASC-4.5", "ASC-5.0"), scatterpoints=1)
plt.ylabel('Generalized Travel Time (s)')
plt.xlabel('Fleet Size')
plt.ylim((500,900))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
handles = []
for i in [3,2,1,0]:
    handle = plt.scatter(NT[i][1], FS[i][1], s=VMT[i][1],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.5)
    handles.append(handle)
plt.legend(handles, ("ASC-3.5", "ASC-4.0", "ASC-4.5", "ASC-5.0"), scatterpoints=1)
plt.ylabel('Fleet Size')
plt.xlabel('Demand (trips/h)')
plt.ylim((0,140))
plt.xlim((0,1300))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
handles = []
for i in [3,2,1,0]:
    handle = plt.scatter(FS[i], TT[i], s=VMT[i],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.1)
    handles.append(handle)
for i in [2]:
    handle = plt.scatter(FS[i], TT[i], s=VMT[i],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.5)
plt.legend(handles, ("ASC-3.5", "ASC-4.0", "ASC-4.5", "ASC-5.0"), scatterpoints=1)
plt.ylabel('Generalized Travel Time (s)')
plt.xlabel('Fleet Size')
plt.ylim((600,900))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
for i in [2]:
    handle = plt.scatter(FS[i], VDT[i], s=VMT[i],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.5)
plt.ylabel('Vehicle In-service Distance Travelled (km)')
plt.xlabel('Fleet Size')
plt.ylim((18,28))
plt.xlim((70,130))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
for i in [2]:
    handle = plt.scatter(FS[i], [731/80, 777/100, 804/120], s=VMT[i],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.5)
plt.ylabel('# Requests Served per Vehicle')
plt.xlabel('Fleet Size')
plt.ylim((6,10))
plt.xlim((70,130))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
for i in [2]:
    handle = plt.scatter(FS[i], TVDT[i], s=VMT[i],
                         c='r' if i == 0 else 'y' if i == 1 else 'g' if i == 2 else 'b',
                         alpha=0.5)
plt.ylabel('Total Vehicle In-service Distance Travelled (km)')
plt.xlabel('Fleet Size')
plt.ylim((1800,2800))
plt.xlim((70,130))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

X = [0.0, -2.54, -3.12, -5.18, -6.89, -7.72]
Y = [0,0,0,0,0,0]
labels = ["walk", "car", "transit", "bike", "p/k&ride", "taxi"]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(X, Y, 'X')
for label, x, y in zip(labels, X, Y):
    ax.annotate(label, [x, y+0.004], va="bottom", ha="left", rotation=45)
ax.spines['bottom'].set_position('zero')
plt.xlim((-9,1))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
X = [-1.28, -1.24, -0.58, -1.12, -0.28, -0.85]
Y = [0,0,0,0,0,0]
labels = ["walk", "car", "transit", "bike", "p/k&ride", "taxi"]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(X, Y, 'X')
for label, x, y in zip(labels, X, Y):
    ax.annotate(label, [x, y+0.004], va="bottom", ha="left", rotation=45)
ax.spines['bottom'].set_position('zero')
plt.xlim((-2,0.5))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
X = [0.0, -2.54, -3.12, -5.18, -6.89, -7.72]
Y = [0,0,0,0,0,0]
labels = ["walk", "car", "transit", "bike", "p/k&ride", "taxi"]

X_ = [-3.5, -4.0, -4.5, -5.0]
Y_ = [0,0,0,0]
labels_ = ["AV+PT 1", "AV+PT 2", "AV+PT 3", "AV+PT 4"]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(X, Y, 'X')
for label, x, y in zip(labels, X, Y):
    ax.annotate(label, [x, y+0.004], va="bottom", ha="left", rotation=45)
ax.plot(X_, Y_, '^')
for label, x, y in zip(labels_, X_, Y_):
    ax.annotate(label, [x, y-0.006], va="top", ha="left", rotation=-45)
ax.spines['bottom'].set_position('zero')
plt.xlim((-9,1))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

WT1 = np.array( [238.7] )
VT1 = np.array( [309.5] )
WT2 = np.array( [180.4,195.6,195.6,179.5,178.4,194.1,191.1,196.2,193.7,180.9] )
VT2 = np.array( [280.2,290.2,290.2,290.5,289.5,290,283.5,292.4,283.4,289.9] )
WT3 = np.array( [230.6,220.4,222.2,231,230.7,223.9,225.9,218.9,231.6,228.2] )
VT3 = np.array( [302.7,303.6,311.9,300.2,309,306.9,307.2,310.3,309.5,305.6] )
WT4 = np.array( [187.9,200.1,187.4,186.5,192.2,180.9,178.1,190.2,190.1,185] )
VT4 = np.array( [290.6,298.4,289.7,286.2,282.1,287.7,282,289.4,284.4,286.3] )

T1 = 1.5*WT1 + VT1
T2 = 1.5*WT2 + VT2
T3 = 1.5*WT3 + VT3
T4 = 1.5*WT4 + VT4

fig, ax1 = plt.subplots()
ax1.boxplot([T1, T2, T3, T4], labels=["IH", "IH+RB", "IH+SA", "IH+SA+RB"], showmeans=True)
ax1.set_xlim((0,4))
ax1.set_ylim((500,750))
ax1.set_ylabel('Generalized Travel Time (s)')
ax2 = ax1.twinx()
ax2.plot([1,2,3,4], [0.99, 0.987, 0.985, 0.987])
ax2.set_ylim((0,1))
ax2.set_ylabel('Service Rate')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
SD1 = np.array( [21546.5] )
SD2 = np.array( [21087.5,20991.9,20311.4,20916.4,21405.4,20982.3,21764.9,21226.9,21412.3,21654.3] )
RD2 = np.array( [11383.6,11180.9,11848.5,11263.1,10805.2,11178.9,10481.7,11224.8,11123.9,10386.3] )
SD3 = np.array( [21470.3,21378.8,21120.6,21302.4,21405.8,20973.4,21005.3,20966.7,20897.5,21705.5] )
SD4 = np.array( [21494.4,21952.8,21345.9,21202.3,21397.2,21167.4,21031.4,21499.5,21553.9,21774.9] )
RD4 = np.array( [10870.1,10356.6,10853.5,10968.8,10968.0,11111.7,11630.5,10860.1,10646.9,10625.6] )

D1 = SD1 / 1000
D2 = (SD2 + RD2) / 1000
D3 = SD3 / 1000
D4 = (SD4 + RD4) / 1000

D1_ = np.mean(D1)
D2_ = np.mean(D2)
D3_ = np.mean(D3)
D4_ = np.mean(D4)

SD1_ = np.mean(SD1) / 1000
SD2_ = np.mean(SD2) / 1000
SD3_ = np.mean(SD3) / 1000
SD4_ = np.mean(SD4) / 1000

fig, ax1 = plt.subplots()
ax1.bar([1,2,3,4], [D1_, D2_, D3_, D4_], 0.3, label="rebalancing")
ax1.bar([1,2,3,4], [SD1_, SD2_, SD1_, SD4_], 0.3, label="in-service")
plt.xticks([1,2,3,4], ["IH", "IH+RB", "IH+SA", "IH+SA+RB"])
ax1.set_xlim((0.5,4.5))
ax1.set_ylim((0,40))
ax1.set_ylabel('Vehicle Distance Travelled (km)')
ax1.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
WT1 = np.array( [260.3] )
VT1 = np.array( [502.3] )
WT2 = np.array( [165.9,185,176.1,176.1,180.2,180.6,180.5,188.9,192.5,203.6] )
VT2 = np.array( [478.4,506.7,488.7,486.7,505.7,479.4,489.9,477.4,497.4,494.4] )
WT3 = np.array( [257.3,259.1,261.2,257.6,248.7,262.9,251.5,260.9,267.8,257.4] )
VT3 = np.array( [511.8,499.2,496,502.1,514.9,494.3,507.6,503.1,497.9,497.9] )
WT4 = np.array( [172.8,175.2,185.6,172.3,171.1,167.1,186.4,199.2,184.6,194.3] )
VT4 = np.array( [474.6,478.4,495.5,496.5,487.8,502.2,482.9,491,477.1,486.2] )

T1 = 1.5*WT1 + VT1
T2 = 1.5*WT2 + VT2
T3 = 1.5*WT3 + VT3
T4 = 1.5*WT4 + VT4

fig, ax1 = plt.subplots()
ax1.boxplot([T1, T2, T3, T4], labels=["IH", "IH+RB", "IH+SA", "IH+SA+RB"], showmeans=True)
ax1.set_xlim((0,4))
ax1.set_ylim((600,950))
ax1.set_ylabel('Generalized Travel Time (s)')
ax2 = ax1.twinx()
ax2.plot([1,2,3,4], [0.98, 0.99, 0.98, 0.986])
ax2.set_ylim((0,1))
ax2.set_ylabel('Service Rate')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
WT1 = np.array( [264.8] )
VT1 = np.array( [422.4] )
WT2 = np.array( [203.3,210.7,205.2,189,185.3,192.5,169.7,191.3,196.4,172.4] )
VT2 = np.array( [484.8,464.5,463.8,460.8,448.5,464.5,456.5,449.1,470.5,443.8] )
WT3 = np.array( [262.1,267.4,268.6,267.2,265,265.2,268.9,270.9,267.7,266.4] )
VT3 = np.array( [421.8,410.1,413,416.3,416.3,416.8,412,412.9,415,427.4] )
WT4 = np.array( [176.2,181.4,179.6,190.4,196.1,164.3,186.6,190.7,193.1,212.2] )
VT4 = np.array( [459.7,457.5,467.3,449.7,455.5,450.8,466.7,466.8,456.5,463.2] )

T1 = 1.5*WT1 + VT1
T2 = 1.5*WT2 + VT2
T3 = 1.5*WT3 + VT3
T4 = 1.5*WT4 + VT4

fig, ax1 = plt.subplots()
ax1.boxplot([T1, T2, T3, T4], labels=["IH", "IH+RB", "IH+SA", "IH+SA+RB"], showmeans=True)
ax1.set_xlim((0,4))
ax1.set_ylim((600,950))
ax1.set_ylabel('Generalized Travel Time (s)')
ax2 = ax1.twinx()
ax2.plot([1,2,3,4], [0.807, 0.965, 0.850, 0.982])
ax2.set_ylim((0,1))
ax2.set_ylabel('Service Rate')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
